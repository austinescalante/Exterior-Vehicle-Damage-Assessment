# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define a function to create the model with specified hyperparameters
def create_model(epochs, hidden_layer_size, activation):
    img_height, img_width = 224, 224
    batch_size = 32

    # Load VGG16 with pre-trained weights
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Freeze all layers in the base model
    for layer in base_model.layers:
        layer.trainable = False

    # Add custom layers with convolutional layers and max-pooling
    model = Sequential([
        base_model,

        GlobalAveragePooling2D(),

        Dense(hidden_layer_size, activation=activation),
        Dense(2, activation='softmax')  # Softmax for multi-class classification
    ])

    # Data Generators
    train_datagen = ImageDataGenerator(rescale=1./255)
    train_gen = train_datagen.flow_from_directory(
        '/content/drive/MyDrive/DataSet Grad Project/dataset_1/training',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    val_datagen = ImageDataGenerator(rescale=1./255)
    val_gen = val_datagen.flow_from_directory(
        '/content/drive/MyDrive/DataSet Grad Project/dataset_1/validation',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compile the model with categorical cross-entropy and the metric 'accuracy'
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Training the model
    history = model.fit(train_gen, epochs=epochs, validation_data=val_gen)

    # Evaluate the model
    evaluation = model.evaluate(val_gen)
    val_accuracy = evaluation[1]
    print(f"Last Validation Accuracy: {val_accuracy}")

    return history, val_accuracy,val_gen,train_gen,model

# Define the hyperparameter values for the grid search
epochs_values = [5, 10, 15]
hidden_layer_sizes = [64, 128, 256]
activations = ['relu', 'tanh', 'sigmoid']

# %%
# Define an empty list to store the results
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score
results = []

# Initialize best_score and best_params
best_score = 0.0
best_params = {}


# Perform grid search
for epochs in epochs_values:
    for hidden_layer_size in hidden_layer_sizes:
        for activation in activations:
            print(f"Training with: Epochs={epochs}, Hidden Layer Size={hidden_layer_size}, Activation={activation}")
            history, val_accuracy,val_gen,train_gen,model = create_model(epochs, hidden_layer_size, activation)
            class_labels = train_gen.class_indices

            class_labels = {v: k for k, v in class_labels.items()}

            true_labels = []
            predicted_classes = []

            for i in range(len(val_gen)):
                batch_images, batch_labels = next(val_gen)
                true_labels.extend(batch_labels.argmax(axis=1))
                predicted_classes.extend(model.predict(batch_images).argmax(axis=1))

            # Calculate the F1 score, precision, recall, and confusion matrix
            f1_score_value = f1_score(true_labels, predicted_classes, average='weighted')
            precision = precision_score(true_labels, predicted_classes, average='weighted')
            recall = recall_score(true_labels, predicted_classes, average='weighted')
            conf_matrix = confusion_matrix(true_labels, predicted_classes)

            print("F1 Score:", f1_score_value)
            print("Precision:", precision)
            print("Recall:", recall)
            print("Confusion Matrix:\n", conf_matrix)

            # Generate a classification report
            report = classification_report(true_labels, predicted_classes, target_names=class_labels.values())

            print("Classification Report:\n", report)


            result = {
                'Epochs': epochs,
                'Hidden Layer Size': hidden_layer_size,
                'Activation': activation,
                'Validation Accuracy': val_accuracy
            }
            results.append(result)

            # Update best hyperparameters and best score
            if val_accuracy > best_score:
                best_score = val_accuracy
                best_params = {
                    'epochs': epochs,
                    'hidden_layer_size': hidden_layer_size,
                    'activation': activation
                }
# Out:
# Training with: Epochs=5, Hidden Layer Size=64, Activation=relu
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 476s 8s/step - loss: 0.5004 - accuracy: 0.7783 - val_loss: 0.4275 - val_accuracy: 0.8022
# Epoch 2/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.4003 - accuracy: 0.8212 - val_loss: 0.3240 - val_accuracy: 0.8674
# Epoch 3/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3568 - accuracy: 0.8473 - val_loss: 0.3194 - val_accuracy: 0.8739
# Epoch 4/5
# 58/58 [==============================] - 8s 136ms/step - loss: 0.3347 - accuracy: 0.8516 - val_loss: 0.3165 - val_accuracy: 0.8739
# Epoch 5/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3201 - accuracy: 0.8630 - val_loss: 0.2930 - val_accuracy: 0.8826
# 15/15 [==============================] - 2s 101ms/step - loss: 0.2930 - accuracy: 0.8826
# Last Validation Accuracy: 0.8826087117195129
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 139ms/step
# F1 Score: 0.8818852708460134
# Precision: 0.8922176575459266
# Recall: 0.8826086956521739
# Confusion Matrix:
#  [[185  45]
#  [  9 221]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.95      0.80      0.87       230
#     01-whole       0.83      0.96      0.89       230
#
#     accuracy                           0.88       460
#    macro avg       0.89      0.88      0.88       460
# weighted avg       0.89      0.88      0.88       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.95      0.80      0.87       230
#     01-whole       0.83      0.96      0.89       230
#
#     accuracy                           0.88       460
#    macro avg       0.89      0.88      0.88       460
# weighted avg       0.89      0.88      0.88       460
#
# Training with: Epochs=5, Hidden Layer Size=64, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 9s 136ms/step - loss: 0.4819 - accuracy: 0.7777 - val_loss: 0.3411 - val_accuracy: 0.8630
# Epoch 2/5
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3849 - accuracy: 0.8207 - val_loss: 0.2920 - val_accuracy: 0.8870
# Epoch 3/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3311 - accuracy: 0.8543 - val_loss: 0.3108 - val_accuracy: 0.8652
# Epoch 4/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3119 - accuracy: 0.8696 - val_loss: 0.2811 - val_accuracy: 0.8870
# Epoch 5/5
# 58/58 [==============================] - 8s 130ms/step - loss: 0.2943 - accuracy: 0.8772 - val_loss: 0.2525 - val_accuracy: 0.9109
# 15/15 [==============================] - 2s 104ms/step - loss: 0.2525 - accuracy: 0.9109
# Last Validation Accuracy: 0.9108695387840271
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 142ms/step
# F1 Score: 0.9107983219111673
# Precision: 0.9121863799283154
# Recall: 0.9108695652173913
# Confusion Matrix:
#  [[203  27]
#  [ 14 216]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.94      0.88      0.91       230
#     01-whole       0.89      0.94      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.94      0.88      0.91       230
#     01-whole       0.89      0.94      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
# Training with: Epochs=5, Hidden Layer Size=64, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 9s 134ms/step - loss: 0.5862 - accuracy: 0.7370 - val_loss: 0.4737 - val_accuracy: 0.8326
# Epoch 2/5
# 58/58 [==============================] - 8s 129ms/step - loss: 0.4597 - accuracy: 0.8076 - val_loss: 0.3819 - val_accuracy: 0.8522
# Epoch 3/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.4033 - accuracy: 0.8228 - val_loss: 0.3378 - val_accuracy: 0.8761
# Epoch 4/5
# 58/58 [==============================] - 8s 130ms/step - loss: 0.3750 - accuracy: 0.8348 - val_loss: 0.3314 - val_accuracy: 0.8587
# Epoch 5/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3557 - accuracy: 0.8457 - val_loss: 0.3091 - val_accuracy: 0.8891
# 15/15 [==============================] - 2s 102ms/step - loss: 0.3091 - accuracy: 0.8891
# Last Validation Accuracy: 0.8891304135322571
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 143ms/step
# F1 Score: 0.8888019907571987
# Precision: 0.8937828790052607
# Recall: 0.8891304347826087
# Confusion Matrix:
#  [[217  13]
#  [ 38 192]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.85      0.94      0.89       230
#     01-whole       0.94      0.83      0.88       230
#
#     accuracy                           0.89       460
#    macro avg       0.89      0.89      0.89       460
# weighted avg       0.89      0.89      0.89       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.85      0.94      0.89       230
#     01-whole       0.94      0.83      0.88       230
#
#     accuracy                           0.89       460
#    macro avg       0.89      0.89      0.89       460
# weighted avg       0.89      0.89      0.89       460
#
# Training with: Epochs=5, Hidden Layer Size=128, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 9s 134ms/step - loss: 0.5009 - accuracy: 0.7658 - val_loss: 0.3452 - val_accuracy: 0.8717
# Epoch 2/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3722 - accuracy: 0.8364 - val_loss: 0.2922 - val_accuracy: 0.8935
# Epoch 3/5
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3370 - accuracy: 0.8478 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 4/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3119 - accuracy: 0.8679 - val_loss: 0.2540 - val_accuracy: 0.9043
# Epoch 5/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3006 - accuracy: 0.8734 - val_loss: 0.3062 - val_accuracy: 0.8500
# 15/15 [==============================] - 2s 102ms/step - loss: 0.3062 - accuracy: 0.8500
# Last Validation Accuracy: 0.8500000238418579
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 139ms/step
# F1 Score: 0.8479819532451112
# Precision: 0.8696272783533968
# Recall: 0.85
# Confusion Matrix:
#  [[169  61]
#  [  8 222]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.95      0.73      0.83       230
#     01-whole       0.78      0.97      0.87       230
#
#     accuracy                           0.85       460
#    macro avg       0.87      0.85      0.85       460
# weighted avg       0.87      0.85      0.85       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.95      0.73      0.83       230
#     01-whole       0.78      0.97      0.87       230
#
#     accuracy                           0.85       460
#    macro avg       0.87      0.85      0.85       460
# weighted avg       0.87      0.85      0.85       460
#
# Training with: Epochs=5, Hidden Layer Size=128, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 9s 136ms/step - loss: 0.4927 - accuracy: 0.7636 - val_loss: 0.3294 - val_accuracy: 0.8652
# Epoch 2/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.3814 - accuracy: 0.8288 - val_loss: 0.2849 - val_accuracy: 0.8935
# Epoch 3/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3423 - accuracy: 0.8484 - val_loss: 0.2784 - val_accuracy: 0.8891
# Epoch 4/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2986 - accuracy: 0.8663 - val_loss: 0.2651 - val_accuracy: 0.9065
# Epoch 5/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.2821 - accuracy: 0.8842 - val_loss: 0.2506 - val_accuracy: 0.8935
# 15/15 [==============================] - 2s 108ms/step - loss: 0.2506 - accuracy: 0.8935
# Last Validation Accuracy: 0.893478274345398
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 138ms/step
# F1 Score: 0.8932557930280026
# Precision: 0.8967860614956442
# Recall: 0.8934782608695652
# Confusion Matrix:
#  [[216  14]
#  [ 35 195]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.86      0.94      0.90       230
#     01-whole       0.93      0.85      0.89       230
#
#     accuracy                           0.89       460
#    macro avg       0.90      0.89      0.89       460
# weighted avg       0.90      0.89      0.89       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.86      0.94      0.90       230
#     01-whole       0.93      0.85      0.89       230
#
#     accuracy                           0.89       460
#    macro avg       0.90      0.89      0.89       460
# weighted avg       0.90      0.89      0.89       460
#
# Training with: Epochs=5, Hidden Layer Size=128, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 9s 136ms/step - loss: 0.5425 - accuracy: 0.7560 - val_loss: 0.4131 - val_accuracy: 0.8522
# Epoch 2/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.4204 - accuracy: 0.8136 - val_loss: 0.3461 - val_accuracy: 0.8522
# Epoch 3/5
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3763 - accuracy: 0.8408 - val_loss: 0.3112 - val_accuracy: 0.8826
# Epoch 4/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3518 - accuracy: 0.8505 - val_loss: 0.2936 - val_accuracy: 0.8848
# Epoch 5/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3375 - accuracy: 0.8533 - val_loss: 0.2797 - val_accuracy: 0.8935
# 15/15 [==============================] - 2s 98ms/step - loss: 0.2797 - accuracy: 0.8935
# Last Validation Accuracy: 0.893478274345398
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 134ms/step
# F1 Score: 0.8934173133029758
# Precision: 0.8943803406657951
# Recall: 0.8934782608695652
# Confusion Matrix:
#  [[200  30]
#  [ 19 211]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.91      0.87      0.89       230
#     01-whole       0.88      0.92      0.90       230
#
#     accuracy                           0.89       460
#    macro avg       0.89      0.89      0.89       460
# weighted avg       0.89      0.89      0.89       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.91      0.87      0.89       230
#     01-whole       0.88      0.92      0.90       230
#
#     accuracy                           0.89       460
#    macro avg       0.89      0.89      0.89       460
# weighted avg       0.89      0.89      0.89       460
#
# Training with: Epochs=5, Hidden Layer Size=256, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 9s 136ms/step - loss: 0.4880 - accuracy: 0.7565 - val_loss: 0.3928 - val_accuracy: 0.8196
# Epoch 2/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3932 - accuracy: 0.8201 - val_loss: 0.2860 - val_accuracy: 0.8891
# Epoch 3/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3282 - accuracy: 0.8620 - val_loss: 0.2865 - val_accuracy: 0.8935
# Epoch 4/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3066 - accuracy: 0.8690 - val_loss: 0.2509 - val_accuracy: 0.9043
# Epoch 5/5
# 58/58 [==============================] - 8s 134ms/step - loss: 0.2847 - accuracy: 0.8750 - val_loss: 0.2401 - val_accuracy: 0.9152
# 15/15 [==============================] - 2s 100ms/step - loss: 0.2401 - accuracy: 0.9152
# Last Validation Accuracy: 0.915217399597168
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 145ms/step
# F1 Score: 0.9152169906285001
# Precision: 0.9152252405527515
# Recall: 0.9152173913043479
# Confusion Matrix:
#  [[210  20]
#  [ 19 211]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.92      0.91      0.92       230
#     01-whole       0.91      0.92      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.92      0.91      0.92       230
#     01-whole       0.91      0.92      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=5, Hidden Layer Size=256, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 9s 134ms/step - loss: 0.4654 - accuracy: 0.7739 - val_loss: 0.3438 - val_accuracy: 0.8609
# Epoch 2/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.3467 - accuracy: 0.8467 - val_loss: 0.2804 - val_accuracy: 0.8935
# Epoch 3/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3040 - accuracy: 0.8707 - val_loss: 0.2461 - val_accuracy: 0.9000
# Epoch 4/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2782 - accuracy: 0.8793 - val_loss: 0.2637 - val_accuracy: 0.8913
# Epoch 5/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.2757 - accuracy: 0.8837 - val_loss: 0.2349 - val_accuracy: 0.9130
# 15/15 [==============================] - 2s 105ms/step - loss: 0.2349 - accuracy: 0.9130
# Last Validation Accuracy: 0.9130434989929199
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 151ms/step
# F1 Score: 0.9129842615012107
# Precision: 0.914170899992418
# Recall: 0.9130434782608695
# Confusion Matrix:
#  [[204  26]
#  [ 14 216]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.94      0.89      0.91       230
#     01-whole       0.89      0.94      0.92       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.94      0.89      0.91       230
#     01-whole       0.89      0.94      0.92       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
# Training with: Epochs=5, Hidden Layer Size=256, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 9s 136ms/step - loss: 0.5556 - accuracy: 0.7397 - val_loss: 0.3999 - val_accuracy: 0.8609
# Epoch 2/5
# 58/58 [==============================] - 8s 134ms/step - loss: 0.4084 - accuracy: 0.8255 - val_loss: 0.3298 - val_accuracy: 0.8739
# Epoch 3/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.3720 - accuracy: 0.8391 - val_loss: 0.3073 - val_accuracy: 0.8870
# Epoch 4/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.3486 - accuracy: 0.8511 - val_loss: 0.2898 - val_accuracy: 0.8913
# Epoch 5/5
# 58/58 [==============================] - 8s 130ms/step - loss: 0.3222 - accuracy: 0.8620 - val_loss: 0.2700 - val_accuracy: 0.8978
# 15/15 [==============================] - 2s 110ms/step - loss: 0.2700 - accuracy: 0.8978
# Last Validation Accuracy: 0.897826075553894
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 147ms/step
# F1 Score: 0.8977676270457116
# Precision: 0.8987381344853067
# Recall: 0.8978260869565218
# Confusion Matrix:
#  [[201  29]
#  [ 18 212]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.92      0.87      0.90       230
#     01-whole       0.88      0.92      0.90       230
#
#     accuracy                           0.90       460
#    macro avg       0.90      0.90      0.90       460
# weighted avg       0.90      0.90      0.90       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.92      0.87      0.90       230
#     01-whole       0.88      0.92      0.90       230
#
#     accuracy                           0.90       460
#    macro avg       0.90      0.90      0.90       460
# weighted avg       0.90      0.90      0.90       460
#
# Training with: Epochs=10, Hidden Layer Size=64, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 9s 136ms/step - loss: 0.5701 - accuracy: 0.7163 - val_loss: 0.4019 - val_accuracy: 0.8457
# Epoch 2/10
# 58/58 [==============================] - 8s 129ms/step - loss: 0.4091 - accuracy: 0.8234 - val_loss: 0.3312 - val_accuracy: 0.8717
# Epoch 3/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3593 - accuracy: 0.8413 - val_loss: 0.2931 - val_accuracy: 0.8913
# Epoch 4/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3354 - accuracy: 0.8495 - val_loss: 0.2742 - val_accuracy: 0.8978
# Epoch 5/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3241 - accuracy: 0.8625 - val_loss: 0.2694 - val_accuracy: 0.8957
# Epoch 6/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3025 - accuracy: 0.8707 - val_loss: 0.2789 - val_accuracy: 0.8826
# Epoch 7/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2925 - accuracy: 0.8734 - val_loss: 0.2464 - val_accuracy: 0.9109
# Epoch 8/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2802 - accuracy: 0.8783 - val_loss: 0.2440 - val_accuracy: 0.9022
# Epoch 9/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.2671 - accuracy: 0.8891 - val_loss: 0.2383 - val_accuracy: 0.9217
# Epoch 10/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2593 - accuracy: 0.8918 - val_loss: 0.2350 - val_accuracy: 0.9087
# 15/15 [==============================] - 2s 101ms/step - loss: 0.2350 - accuracy: 0.9087
# Last Validation Accuracy: 0.908695638179779
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 157ms/step
# F1 Score: 0.9086680281370547
# Precision: 0.9091907033083504
# Recall: 0.908695652173913
# Confusion Matrix:
#  [[213  17]
#  [ 25 205]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.89      0.93      0.91       230
#     01-whole       0.92      0.89      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.89      0.93      0.91       230
#     01-whole       0.92      0.89      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
# Training with: Epochs=10, Hidden Layer Size=64, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 8s 128ms/step - loss: 0.5035 - accuracy: 0.7592 - val_loss: 0.3483 - val_accuracy: 0.8717
# Epoch 2/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3685 - accuracy: 0.8391 - val_loss: 0.2932 - val_accuracy: 0.8891
# Epoch 3/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3390 - accuracy: 0.8598 - val_loss: 0.2661 - val_accuracy: 0.9065
# Epoch 4/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3210 - accuracy: 0.8625 - val_loss: 0.2842 - val_accuracy: 0.8848
# Epoch 5/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.3065 - accuracy: 0.8685 - val_loss: 0.2804 - val_accuracy: 0.8870
# Epoch 6/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2768 - accuracy: 0.8870 - val_loss: 0.2411 - val_accuracy: 0.9152
# Epoch 7/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.2701 - accuracy: 0.8875 - val_loss: 0.2414 - val_accuracy: 0.9065
# Epoch 8/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2577 - accuracy: 0.8935 - val_loss: 0.2465 - val_accuracy: 0.9022
# Epoch 9/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2487 - accuracy: 0.8967 - val_loss: 0.2313 - val_accuracy: 0.9239
# Epoch 10/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.2412 - accuracy: 0.8995 - val_loss: 0.2454 - val_accuracy: 0.9065
# 15/15 [==============================] - 2s 98ms/step - loss: 0.2454 - accuracy: 0.9065
# Last Validation Accuracy: 0.906521737575531
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 134ms/step
# F1 Score: 0.9063619880798526
# Precision: 0.9093149850587182
# Recall: 0.9065217391304348
# Confusion Matrix:
#  [[199  31]
#  [ 12 218]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.94      0.87      0.90       230
#     01-whole       0.88      0.95      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.94      0.87      0.90       230
#     01-whole       0.88      0.95      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
# Training with: Epochs=10, Hidden Layer Size=64, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 9s 133ms/step - loss: 0.5940 - accuracy: 0.7413 - val_loss: 0.4749 - val_accuracy: 0.8500
# Epoch 2/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.4631 - accuracy: 0.8103 - val_loss: 0.3835 - val_accuracy: 0.8587
# Epoch 3/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.4078 - accuracy: 0.8217 - val_loss: 0.3416 - val_accuracy: 0.8739
# Epoch 4/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3895 - accuracy: 0.8364 - val_loss: 0.3196 - val_accuracy: 0.8870
# Epoch 5/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3629 - accuracy: 0.8370 - val_loss: 0.3018 - val_accuracy: 0.8891
# Epoch 6/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.3423 - accuracy: 0.8533 - val_loss: 0.2868 - val_accuracy: 0.8891
# Epoch 7/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3326 - accuracy: 0.8560 - val_loss: 0.2772 - val_accuracy: 0.8957
# Epoch 8/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3272 - accuracy: 0.8560 - val_loss: 0.2912 - val_accuracy: 0.8848
# Epoch 9/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3179 - accuracy: 0.8652 - val_loss: 0.2791 - val_accuracy: 0.8935
# Epoch 10/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3039 - accuracy: 0.8717 - val_loss: 0.2588 - val_accuracy: 0.8978
# 15/15 [==============================] - 2s 99ms/step - loss: 0.2588 - accuracy: 0.8978
# Last Validation Accuracy: 0.897826075553894
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 130ms/step
# F1 Score: 0.8977676270457116
# Precision: 0.8987381344853067
# Recall: 0.8978260869565218
# Confusion Matrix:
#  [[212  18]
#  [ 29 201]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.88      0.92      0.90       230
#     01-whole       0.92      0.87      0.90       230
#
#     accuracy                           0.90       460
#    macro avg       0.90      0.90      0.90       460
# weighted avg       0.90      0.90      0.90       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.88      0.92      0.90       230
#     01-whole       0.92      0.87      0.90       230
#
#     accuracy                           0.90       460
#    macro avg       0.90      0.90      0.90       460
# weighted avg       0.90      0.90      0.90       460
#
# Training with: Epochs=10, Hidden Layer Size=128, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 9s 135ms/step - loss: 0.5147 - accuracy: 0.7489 - val_loss: 0.3550 - val_accuracy: 0.8565
# Epoch 2/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3882 - accuracy: 0.8272 - val_loss: 0.2963 - val_accuracy: 0.8870
# Epoch 3/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.3475 - accuracy: 0.8467 - val_loss: 0.2935 - val_accuracy: 0.8870
# Epoch 4/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3160 - accuracy: 0.8641 - val_loss: 0.2742 - val_accuracy: 0.8978
# Epoch 5/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.2950 - accuracy: 0.8734 - val_loss: 0.2501 - val_accuracy: 0.8978
# Epoch 6/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3017 - accuracy: 0.8723 - val_loss: 0.2521 - val_accuracy: 0.9109
# Epoch 7/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.2781 - accuracy: 0.8848 - val_loss: 0.2330 - val_accuracy: 0.9239
# Epoch 8/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2622 - accuracy: 0.8875 - val_loss: 0.2399 - val_accuracy: 0.9130
# Epoch 9/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.2709 - accuracy: 0.8837 - val_loss: 0.2428 - val_accuracy: 0.9043
# Epoch 10/10
# 58/58 [==============================] - 8s 127ms/step - loss: 0.2512 - accuracy: 0.8924 - val_loss: 0.2264 - val_accuracy: 0.9174
# 15/15 [==============================] - 2s 98ms/step - loss: 0.2264 - accuracy: 0.9174
# Last Validation Accuracy: 0.917391300201416
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 136ms/step
# F1 Score: 0.9173772475468417
# Precision: 0.9176755447941888
# Recall: 0.9173913043478261
# Confusion Matrix:
#  [[214  16]
#  [ 22 208]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.91      0.93      0.92       230
#     01-whole       0.93      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.91      0.93      0.92       230
#     01-whole       0.93      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=128, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 9s 138ms/step - loss: 0.4671 - accuracy: 0.7804 - val_loss: 0.3131 - val_accuracy: 0.8783
# Epoch 2/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.3592 - accuracy: 0.8353 - val_loss: 0.2804 - val_accuracy: 0.8913
# Epoch 3/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3246 - accuracy: 0.8598 - val_loss: 0.2561 - val_accuracy: 0.9043
# Epoch 4/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3402 - accuracy: 0.8511 - val_loss: 0.2564 - val_accuracy: 0.9000
# Epoch 5/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2970 - accuracy: 0.8750 - val_loss: 0.2468 - val_accuracy: 0.9174
# Epoch 6/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.2754 - accuracy: 0.8804 - val_loss: 0.2763 - val_accuracy: 0.8804
# Epoch 7/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2556 - accuracy: 0.8908 - val_loss: 0.2457 - val_accuracy: 0.9130
# Epoch 8/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2539 - accuracy: 0.8924 - val_loss: 0.2588 - val_accuracy: 0.9043
# Epoch 9/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2388 - accuracy: 0.9000 - val_loss: 0.2300 - val_accuracy: 0.9174
# Epoch 10/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2472 - accuracy: 0.8951 - val_loss: 0.3414 - val_accuracy: 0.8696
# 15/15 [==============================] - 2s 101ms/step - loss: 0.3414 - accuracy: 0.8696
# Last Validation Accuracy: 0.8695651888847351
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 155ms/step
# F1 Score: 0.867876838235294
# Precision: 0.8894732648019763
# Recall: 0.8695652173913043
# Confusion Matrix:
#  [[226   4]
#  [ 56 174]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.80      0.98      0.88       230
#     01-whole       0.98      0.76      0.85       230
#
#     accuracy                           0.87       460
#    macro avg       0.89      0.87      0.87       460
# weighted avg       0.89      0.87      0.87       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.80      0.98      0.88       230
#     01-whole       0.98      0.76      0.85       230
#
#     accuracy                           0.87       460
#    macro avg       0.89      0.87      0.87       460
# weighted avg       0.89      0.87      0.87       460
#
# Training with: Epochs=10, Hidden Layer Size=128, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 9s 138ms/step - loss: 0.6853 - accuracy: 0.6076 - val_loss: 0.5037 - val_accuracy: 0.8457
# Epoch 2/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.4792 - accuracy: 0.7973 - val_loss: 0.3925 - val_accuracy: 0.8565
# Epoch 3/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.4135 - accuracy: 0.8174 - val_loss: 0.3409 - val_accuracy: 0.8848
# Epoch 4/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3846 - accuracy: 0.8277 - val_loss: 0.3126 - val_accuracy: 0.8870
# Epoch 5/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3541 - accuracy: 0.8511 - val_loss: 0.2939 - val_accuracy: 0.8891
# Epoch 6/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3404 - accuracy: 0.8505 - val_loss: 0.2912 - val_accuracy: 0.8935
# Epoch 7/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3250 - accuracy: 0.8576 - val_loss: 0.2692 - val_accuracy: 0.9043
# Epoch 8/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.3114 - accuracy: 0.8690 - val_loss: 0.2613 - val_accuracy: 0.9043
# Epoch 9/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3067 - accuracy: 0.8652 - val_loss: 0.2562 - val_accuracy: 0.9087
# Epoch 10/10
# 58/58 [==============================] - 7s 128ms/step - loss: 0.3016 - accuracy: 0.8641 - val_loss: 0.2553 - val_accuracy: 0.9022
# 15/15 [==============================] - 2s 90ms/step - loss: 0.2553 - accuracy: 0.9022
# Last Validation Accuracy: 0.9021739363670349
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 144ms/step
# F1 Score: 0.9021179407884471
# Precision: 0.9030959283048182
# Recall: 0.9021739130434783
# Confusion Matrix:
#  [[213  17]
#  [ 28 202]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.88      0.93      0.90       230
#     01-whole       0.92      0.88      0.90       230
#
#     accuracy                           0.90       460
#    macro avg       0.90      0.90      0.90       460
# weighted avg       0.90      0.90      0.90       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.88      0.93      0.90       230
#     01-whole       0.92      0.88      0.90       230
#
#     accuracy                           0.90       460
#    macro avg       0.90      0.90      0.90       460
# weighted avg       0.90      0.90      0.90       460
#
# Training with: Epochs=10, Hidden Layer Size=256, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 9s 137ms/step - loss: 0.4932 - accuracy: 0.7582 - val_loss: 0.3626 - val_accuracy: 0.8283
# Epoch 2/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3743 - accuracy: 0.8326 - val_loss: 0.3125 - val_accuracy: 0.8717
# Epoch 3/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3250 - accuracy: 0.8609 - val_loss: 0.2620 - val_accuracy: 0.9043
# Epoch 4/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3175 - accuracy: 0.8576 - val_loss: 0.2535 - val_accuracy: 0.9130
# Epoch 5/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2943 - accuracy: 0.8734 - val_loss: 0.2461 - val_accuracy: 0.9174
# Epoch 6/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.2843 - accuracy: 0.8804 - val_loss: 0.2508 - val_accuracy: 0.9087
# Epoch 7/10
# 58/58 [==============================] - 7s 128ms/step - loss: 0.2559 - accuracy: 0.8935 - val_loss: 0.2314 - val_accuracy: 0.9196
# Epoch 8/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.2489 - accuracy: 0.9033 - val_loss: 0.3072 - val_accuracy: 0.8630
# Epoch 9/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2636 - accuracy: 0.8793 - val_loss: 0.2380 - val_accuracy: 0.9043
# Epoch 10/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2336 - accuracy: 0.9027 - val_loss: 0.2241 - val_accuracy: 0.9217
# 15/15 [==============================] - 2s 101ms/step - loss: 0.2241 - accuracy: 0.9217
# Last Validation Accuracy: 0.9217391014099121
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 147ms/step
# F1 Score: 0.9217332123411979
# Precision: 0.9218667271764616
# Recall: 0.9217391304347826
# Confusion Matrix:
#  [[210  20]
#  [ 16 214]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.93      0.91      0.92       230
#     01-whole       0.91      0.93      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.93      0.91      0.92       230
#     01-whole       0.91      0.93      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=256, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 9s 134ms/step - loss: 0.5287 - accuracy: 0.7223 - val_loss: 0.3384 - val_accuracy: 0.8565
# Epoch 2/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.3811 - accuracy: 0.8299 - val_loss: 0.2878 - val_accuracy: 0.8891
# Epoch 3/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3413 - accuracy: 0.8522 - val_loss: 0.2979 - val_accuracy: 0.8761
# Epoch 4/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3120 - accuracy: 0.8674 - val_loss: 0.3310 - val_accuracy: 0.8435
# Epoch 5/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.3025 - accuracy: 0.8663 - val_loss: 0.2643 - val_accuracy: 0.9000
# Epoch 6/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2830 - accuracy: 0.8810 - val_loss: 0.2352 - val_accuracy: 0.9130
# Epoch 7/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.2580 - accuracy: 0.8935 - val_loss: 0.2995 - val_accuracy: 0.8804
# Epoch 8/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2652 - accuracy: 0.8832 - val_loss: 0.2234 - val_accuracy: 0.9174
# Epoch 9/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2557 - accuracy: 0.8951 - val_loss: 0.2627 - val_accuracy: 0.8804
# Epoch 10/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2317 - accuracy: 0.8995 - val_loss: 0.2244 - val_accuracy: 0.9152
# ...
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 9s 133ms/step - loss: 0.6405 - accuracy: 0.6446 - val_loss: 0.4934 - val_accuracy: 0.8500
# Epoch 2/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.4765 - accuracy: 0.8043 - val_loss: 0.3989 - val_accuracy: 0.8522
# Epoch 3/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.4206 - accuracy: 0.8174 - val_loss: 0.3487 - val_accuracy: 0.8696
# Epoch 4/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3865 - accuracy: 0.8321 - val_loss: 0.3171 - val_accuracy: 0.8870
# Epoch 5/15
# 58/58 [==============================] - 8s 129ms/step - loss: 0.3609 - accuracy: 0.8364 - val_loss: 0.3185 - val_accuracy: 0.8761
# Epoch 6/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.3464 - accuracy: 0.8495 - val_loss: 0.2884 - val_accuracy: 0.8848
# Epoch 7/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.3291 - accuracy: 0.8592 - val_loss: 0.2856 - val_accuracy: 0.8935
# Epoch 8/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.3167 - accuracy: 0.8636 - val_loss: 0.2689 - val_accuracy: 0.8978
# Epoch 9/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3060 - accuracy: 0.8674 - val_loss: 0.2601 - val_accuracy: 0.9022
# Epoch 10/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2999 - accuracy: 0.8701 - val_loss: 0.2872 - val_accuracy: 0.8804
# Epoch 11/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.2910 - accuracy: 0.8815 - val_loss: 0.2508 - val_accuracy: 0.9109
# Epoch 12/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2796 - accuracy: 0.8832 - val_loss: 0.2458 - val_accuracy: 0.9087
# Epoch 13/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.2753 - accuracy: 0.8799 - val_loss: 0.2536 - val_accuracy: 0.8957
# Epoch 14/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.2748 - accuracy: 0.8837 - val_loss: 0.2486 - val_accuracy: 0.9130
# Epoch 15/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2617 - accuracy: 0.8880 - val_loss: 0.2429 - val_accuracy: 0.9217
# 15/15 [==============================] - 2s 104ms/step - loss: 0.2429 - accuracy: 0.9217
# Last Validation Accuracy: 0.9217391014099121
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 140ms/step
# F1 Score: 0.9216858353510896
# Precision: 0.9228902873606794
# Recall: 0.9217391304347826
# Confusion Matrix:
#  [[206  24]
#  [ 12 218]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.94      0.90      0.92       230
#     01-whole       0.90      0.95      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.94      0.90      0.92       230
#     01-whole       0.90      0.95      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=15, Hidden Layer Size=256, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 9s 135ms/step - loss: 0.5621 - accuracy: 0.6957 - val_loss: 0.3609 - val_accuracy: 0.8543
# Epoch 2/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.3847 - accuracy: 0.8255 - val_loss: 0.2970 - val_accuracy: 0.8913
# Epoch 3/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3416 - accuracy: 0.8516 - val_loss: 0.2804 - val_accuracy: 0.8978
# Epoch 4/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3246 - accuracy: 0.8625 - val_loss: 0.2574 - val_accuracy: 0.9065
# Epoch 5/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3001 - accuracy: 0.8723 - val_loss: 0.2584 - val_accuracy: 0.9087
# Epoch 6/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2888 - accuracy: 0.8783 - val_loss: 0.2410 - val_accuracy: 0.9130
# Epoch 7/15
# 58/58 [==============================] - 7s 129ms/step - loss: 0.2707 - accuracy: 0.8870 - val_loss: 0.2376 - val_accuracy: 0.9109
# Epoch 8/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2537 - accuracy: 0.8880 - val_loss: 0.2347 - val_accuracy: 0.9152
# Epoch 9/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.2441 - accuracy: 0.9000 - val_loss: 0.2561 - val_accuracy: 0.8891
# Epoch 10/15
# 58/58 [==============================] - 7s 129ms/step - loss: 0.2331 - accuracy: 0.9005 - val_loss: 0.2353 - val_accuracy: 0.9087
# Epoch 11/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.2312 - accuracy: 0.9043 - val_loss: 0.2432 - val_accuracy: 0.9109
# Epoch 12/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.2321 - accuracy: 0.8984 - val_loss: 0.2237 - val_accuracy: 0.9174
# Epoch 13/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.2087 - accuracy: 0.9130 - val_loss: 0.2319 - val_accuracy: 0.9152
# Epoch 14/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.2028 - accuracy: 0.9190 - val_loss: 0.2356 - val_accuracy: 0.9000
# Epoch 15/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1997 - accuracy: 0.9223 - val_loss: 0.2164 - val_accuracy: 0.9239
# 15/15 [==============================] - 2s 106ms/step - loss: 0.2164 - accuracy: 0.9239
# Last Validation Accuracy: 0.9239130616188049
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 136ms/step
# F1 Score: 0.9239040529363111
# Precision: 0.924113475177305
# Recall: 0.9239130434782609
# Confusion Matrix:
#  [[210  20]
#  [ 15 215]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.93      0.91      0.92       230
#     01-whole       0.91      0.93      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.93      0.91      0.92       230
#     01-whole       0.91      0.93      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=15, Hidden Layer Size=256, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 9s 133ms/step - loss: 0.4705 - accuracy: 0.7728 - val_loss: 0.3068 - val_accuracy: 0.8783
# Epoch 2/15
# 58/58 [==============================] - 7s 126ms/step - loss: 0.3534 - accuracy: 0.8565 - val_loss: 0.2691 - val_accuracy: 0.8978
# Epoch 3/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.3115 - accuracy: 0.8658 - val_loss: 0.2574 - val_accuracy: 0.9087
# Epoch 4/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.3087 - accuracy: 0.8701 - val_loss: 0.2423 - val_accuracy: 0.9152
# Epoch 5/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.3138 - accuracy: 0.8652 - val_loss: 0.2824 - val_accuracy: 0.8739
# Epoch 6/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2821 - accuracy: 0.8804 - val_loss: 0.2438 - val_accuracy: 0.9065
# Epoch 7/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2447 - accuracy: 0.8995 - val_loss: 0.2257 - val_accuracy: 0.9174
# Epoch 8/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.2398 - accuracy: 0.8973 - val_loss: 0.2249 - val_accuracy: 0.9217
# Epoch 9/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.2269 - accuracy: 0.9082 - val_loss: 0.2221 - val_accuracy: 0.9239
# Epoch 10/15
# 58/58 [==============================] - 7s 129ms/step - loss: 0.2224 - accuracy: 0.9114 - val_loss: 0.2240 - val_accuracy: 0.9152
# Epoch 11/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2294 - accuracy: 0.9027 - val_loss: 0.2363 - val_accuracy: 0.8978
# Epoch 12/15
# 58/58 [==============================] - 7s 127ms/step - loss: 0.2193 - accuracy: 0.9109 - val_loss: 0.2148 - val_accuracy: 0.9196
# Epoch 13/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.2207 - accuracy: 0.9071 - val_loss: 0.2293 - val_accuracy: 0.9196
# Epoch 14/15
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1985 - accuracy: 0.9196 - val_loss: 0.2298 - val_accuracy: 0.9239
# Epoch 15/15
# 58/58 [==============================] - 8s 129ms/step - loss: 0.2060 - accuracy: 0.9190 - val_loss: 0.2340 - val_accuracy: 0.9217
# 15/15 [==============================] - 1s 91ms/step - loss: 0.2340 - accuracy: 0.9217
# Last Validation Accuracy: 0.9217391014099121
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 139ms/step
# F1 Score: 0.9216665720610774
# Precision: 0.9233075288403157
# Recall: 0.9217391304347826
# Confusion Matrix:
#  [[205  25]
#  [ 11 219]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.95      0.89      0.92       230
#     01-whole       0.90      0.95      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.95      0.89      0.92       230
#     01-whole       0.90      0.95      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=15, Hidden Layer Size=256, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 9s 132ms/step - loss: 0.5581 - accuracy: 0.7359 - val_loss: 0.4057 - val_accuracy: 0.8522
# Epoch 2/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.4316 - accuracy: 0.8092 - val_loss: 0.3410 - val_accuracy: 0.8652
# Epoch 3/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3830 - accuracy: 0.8332 - val_loss: 0.3082 - val_accuracy: 0.8935
# Epoch 4/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.3570 - accuracy: 0.8413 - val_loss: 0.2969 - val_accuracy: 0.8913
# Epoch 5/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3350 - accuracy: 0.8533 - val_loss: 0.2765 - val_accuracy: 0.8935
# Epoch 6/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.3186 - accuracy: 0.8712 - val_loss: 0.2634 - val_accuracy: 0.9022
# Epoch 7/15
# 58/58 [==============================] - 8s 129ms/step - loss: 0.3047 - accuracy: 0.8679 - val_loss: 0.2795 - val_accuracy: 0.8913
# Epoch 8/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.3022 - accuracy: 0.8728 - val_loss: 0.2581 - val_accuracy: 0.8935
# Epoch 9/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2948 - accuracy: 0.8701 - val_loss: 0.2955 - val_accuracy: 0.8739
# Epoch 10/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2781 - accuracy: 0.8832 - val_loss: 0.2409 - val_accuracy: 0.9109
# Epoch 11/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2636 - accuracy: 0.8935 - val_loss: 0.2367 - val_accuracy: 0.9174
# Epoch 12/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2609 - accuracy: 0.8902 - val_loss: 0.2352 - val_accuracy: 0.9152
# Epoch 13/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2626 - accuracy: 0.8826 - val_loss: 0.2357 - val_accuracy: 0.9130
# Epoch 14/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2487 - accuracy: 0.8995 - val_loss: 0.3140 - val_accuracy: 0.8739
# Epoch 15/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2454 - accuracy: 0.9016 - val_loss: 0.2328 - val_accuracy: 0.9109
# 15/15 [==============================] - 2s 104ms/step - loss: 0.2328 - accuracy: 0.9109
# Last Validation Accuracy: 0.9108695387840271
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 138ms/step
# F1 Score: 0.9108185682739184
# Precision: 0.9118115159438414
# Recall: 0.9108695652173913
# Confusion Matrix:
#  [[215  15]
#  [ 26 204]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.89      0.93      0.91       230
#     01-whole       0.93      0.89      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
#               precision    recall  f1-score   support
#
#    00-damage       0.89      0.93      0.91       230
#     01-whole       0.93      0.89      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460

# %%
# Print the best hyperparameters and the best validation accuracy
print("Best Hyperparameters: ", best_params)
print("Best Validation Accuracy: ", best_score)

# Create a DataFrame from the results list
df = pd.DataFrame(results)

# Group the DataFrame by the 'Activation' column
grouped = df.groupby('Activation')

# Print the grouped DataFrame
for name, group in grouped:
    print(name)
    print(group)
# Out:
# Best Hyperparameters:  {'epochs': 15, 'hidden_layer_size': 256, 'activation': 'relu'}
# Best Validation Accuracy:  0.9239130616188049
# relu
#     Epochs  Hidden Layer Size Activation  Validation Accuracy
# 0        5                 64       relu             0.882609
# 3        5                128       relu             0.850000
# 6        5                256       relu             0.915217
# 9       10                 64       relu             0.908696
# 12      10                128       relu             0.917391
# 15      10                256       relu             0.921739
# 18      15                 64       relu             0.919565
# 21      15                128       relu             0.921739
# 24      15                256       relu             0.923913
# sigmoid
#     Epochs  Hidden Layer Size Activation  Validation Accuracy
# 2        5                 64    sigmoid             0.889130
# 5        5                128    sigmoid             0.893478
# 8        5                256    sigmoid             0.897826
# 11      10                 64    sigmoid             0.897826
# 14      10                128    sigmoid             0.902174
# 17      10                256    sigmoid             0.900000
# 20      15                 64    sigmoid             0.882609
# 23      15                128    sigmoid             0.921739
# 26      15                256    sigmoid             0.910870
# tanh
#     Epochs  Hidden Layer Size Activation  Validation Accuracy
# 1        5                 64       tanh             0.910870
# 4        5                128       tanh             0.893478
# 7        5                256       tanh             0.913043
# 10      10                 64       tanh             0.906522
# 13      10                128       tanh             0.869565
# 16      10                256       tanh             0.915217
# 19      15                 64       tanh             0.917391
# 22      15                128       tanh             0.910870
# 25      15                256       tanh             0.921739
