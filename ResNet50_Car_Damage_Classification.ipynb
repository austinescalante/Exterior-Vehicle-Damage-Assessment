# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define a function to create the model with specified hyperparameters
def create_model(epochs, hidden_layer_size, activation):
    img_height, img_width = 224, 224
    batch_size = 32

    # Load VGG16 with pre-trained weights
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Freeze all layers in the base model
    for layer in base_model.layers:
        layer.trainable = False

    # Add custom layers with convolutional layers and max-pooling
    model = Sequential([
        base_model,

        GlobalAveragePooling2D(),

        Dense(hidden_layer_size, activation=activation),
        Dense(2, activation='softmax')  # Softmax for multi-class classification
    ])

    # Data Generators
    train_datagen = ImageDataGenerator(rescale=1./255)
    train_gen = train_datagen.flow_from_directory(
        '/content/drive/MyDrive/DataSet Grad Project/dataset_1/training',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    val_datagen = ImageDataGenerator(rescale=1./255)
    val_gen = val_datagen.flow_from_directory(
        '/content/drive/MyDrive/DataSet Grad Project/dataset_1/validation',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compile the model with categorical cross-entropy and the metric 'accuracy'
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Training the model
    history = model.fit(train_gen, epochs=epochs, validation_data=val_gen)

    # Evaluate the model
    evaluation = model.evaluate(val_gen)
    val_accuracy = evaluation[1]
    print(f"Last Validation Accuracy: {val_accuracy}")

    return history, val_accuracy,val_gen,train_gen,model

# Define the hyperparameter values for the grid search
epochs_values = [5, 10, 15]
hidden_layer_sizes = [64, 128, 256]
activations = ['relu', 'tanh', 'sigmoid']

# %%
# Define an empty list to store the results
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score
results = []

# Initialize best_score and best_params
best_score = 0.0
best_params = {}


# Perform grid search
for epochs in epochs_values:
    for hidden_layer_size in hidden_layer_sizes:
        for activation in activations:
            print(f"Training with: Epochs={epochs}, Hidden Layer Size={hidden_layer_size}, Activation={activation}")
            history, val_accuracy,val_gen,train_gen,model = create_model(epochs, hidden_layer_size, activation)
            class_labels = train_gen.class_indices

            class_labels = {v: k for k, v in class_labels.items()}

            true_labels = []
            predicted_classes = []

            for i in range(len(val_gen)):
                batch_images, batch_labels = next(val_gen)
                true_labels.extend(batch_labels.argmax(axis=1))
                predicted_classes.extend(model.predict(batch_images).argmax(axis=1))

            # Calculate the F1 score, precision, recall, and confusion matrix
            f1_score_value = f1_score(true_labels, predicted_classes, average='weighted')
            precision = precision_score(true_labels, predicted_classes, average='weighted')
            recall = recall_score(true_labels, predicted_classes, average='weighted')
            conf_matrix = confusion_matrix(true_labels, predicted_classes)

            print("F1 Score:", f1_score_value)
            print("Precision:", precision)
            print("Recall:", recall)
            print("Confusion Matrix:\n", conf_matrix)

            # Generate a classification report
            report = classification_report(true_labels, predicted_classes, target_names=class_labels.values())

            print("Classification Report:\n", report)


            result = {
                'Epochs': epochs,
                'Hidden Layer Size': hidden_layer_size,
                'Activation': activation,
                'Validation Accuracy': val_accuracy
            }
            results.append(result)

            # Update best hyperparameters and best score
            if val_accuracy > best_score:
                best_score = val_accuracy
                best_params = {
                    'epochs': epochs,
                    'hidden_layer_size': hidden_layer_size,
                    'activation': activation
                }
# Out:
# Training with: Epochs=5, Hidden Layer Size=64, Activation=relu
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 394s 7s/step - loss: 0.6897 - accuracy: 0.5505 - val_loss: 0.6700 - val_accuracy: 0.5565
# Epoch 2/5
# 58/58 [==============================] - 8s 139ms/step - loss: 0.6483 - accuracy: 0.6136 - val_loss: 0.6651 - val_accuracy: 0.5543
# Epoch 3/5
# 58/58 [==============================] - 8s 142ms/step - loss: 0.6396 - accuracy: 0.6332 - val_loss: 0.6465 - val_accuracy: 0.5848
# Epoch 4/5
# 58/58 [==============================] - 8s 143ms/step - loss: 0.6437 - accuracy: 0.6332 - val_loss: 0.6248 - val_accuracy: 0.6348
# Epoch 5/5
# 58/58 [==============================] - 8s 141ms/step - loss: 0.6072 - accuracy: 0.6636 - val_loss: 0.6175 - val_accuracy: 0.6391
# 15/15 [==============================] - 2s 107ms/step - loss: 0.6175 - accuracy: 0.6391
# Last Validation Accuracy: 0.6391304135322571
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 944ms/step
# F1 Score: 0.6240942028985508
# Precision: 0.6656314699792961
# Recall: 0.6391304347826087
# Confusion Matrix:
#  [[193  37]
#  [129 101]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.60      0.84      0.70       230
#     01-whole       0.73      0.44      0.55       230
#
#     accuracy                           0.64       460
#    macro avg       0.67      0.64      0.62       460
# weighted avg       0.67      0.64      0.62       460
#
# Training with: Epochs=5, Hidden Layer Size=64, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 13s 160ms/step - loss: 0.7077 - accuracy: 0.5576 - val_loss: 0.7025 - val_accuracy: 0.5217
# Epoch 2/5
# 58/58 [==============================] - 8s 139ms/step - loss: 0.6515 - accuracy: 0.6332 - val_loss: 0.6392 - val_accuracy: 0.6413
# Epoch 3/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6351 - accuracy: 0.6359 - val_loss: 0.6226 - val_accuracy: 0.6435
# Epoch 4/5
# 58/58 [==============================] - 8s 142ms/step - loss: 0.6017 - accuracy: 0.6783 - val_loss: 0.6146 - val_accuracy: 0.6739
# Epoch 5/5
# 58/58 [==============================] - 8s 142ms/step - loss: 0.5990 - accuracy: 0.6886 - val_loss: 0.7228 - val_accuracy: 0.5696
# 15/15 [==============================] - 2s 108ms/step - loss: 0.7228 - accuracy: 0.5696
# Last Validation Accuracy: 0.5695652365684509
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 913ms/step
# F1 Score: 0.49376375641966247
# Precision: 0.6734539969834087
# Recall: 0.5695652173913044
# Confusion Matrix:
#  [[ 42 188]
#  [ 10 220]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.81      0.18      0.30       230
#     01-whole       0.54      0.96      0.69       230
#
#     accuracy                           0.57       460
#    macro avg       0.67      0.57      0.49       460
# weighted avg       0.67      0.57      0.49       460
#
# Training with: Epochs=5, Hidden Layer Size=64, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 12s 155ms/step - loss: 0.6913 - accuracy: 0.5370 - val_loss: 0.6870 - val_accuracy: 0.5174
# Epoch 2/5
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6626 - accuracy: 0.6212 - val_loss: 0.6709 - val_accuracy: 0.5565
# Epoch 3/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6340 - accuracy: 0.6609 - val_loss: 0.6489 - val_accuracy: 0.6370
# Epoch 4/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.6269 - accuracy: 0.6418 - val_loss: 0.6779 - val_accuracy: 0.5696
# Epoch 5/5
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6085 - accuracy: 0.6685 - val_loss: 0.6181 - val_accuracy: 0.6478
# 15/15 [==============================] - 2s 101ms/step - loss: 0.6181 - accuracy: 0.6478
# Last Validation Accuracy: 0.647826075553894
# 1/1 [==============================] - 1s 944ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 1s 947ms/step
# F1 Score: 0.6344478455380268
# Precision: 0.6731774293560102
# Recall: 0.6478260869565218
# Confusion Matrix:
#  [[193  37]
#  [125 105]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.61      0.84      0.70       230
#     01-whole       0.74      0.46      0.56       230
#
#     accuracy                           0.65       460
#    macro avg       0.67      0.65      0.63       460
# weighted avg       0.67      0.65      0.63       460
#
# Training with: Epochs=5, Hidden Layer Size=128, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 13s 152ms/step - loss: 0.6956 - accuracy: 0.5712 - val_loss: 0.6793 - val_accuracy: 0.5543
# Epoch 2/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6477 - accuracy: 0.6239 - val_loss: 0.6464 - val_accuracy: 0.6391
# Epoch 3/5
# 58/58 [==============================] - 8s 139ms/step - loss: 0.6441 - accuracy: 0.6380 - val_loss: 0.6360 - val_accuracy: 0.6065
# Epoch 4/5
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6065 - accuracy: 0.6804 - val_loss: 0.6294 - val_accuracy: 0.6196
# Epoch 5/5
# 58/58 [==============================] - 8s 143ms/step - loss: 0.5991 - accuracy: 0.6772 - val_loss: 0.6112 - val_accuracy: 0.6543
# 15/15 [==============================] - 2s 108ms/step - loss: 0.6112 - accuracy: 0.6543
# Last Validation Accuracy: 0.654347836971283
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 1s 962ms/step
# F1 Score: 0.6427158286560076
# Precision: 0.6774575644954468
# Recall: 0.6543478260869565
# Confusion Matrix:
#  [[192  38]
#  [121 109]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.61      0.83      0.71       230
#     01-whole       0.74      0.47      0.58       230
#
#     accuracy                           0.65       460
#    macro avg       0.68      0.65      0.64       460
# weighted avg       0.68      0.65      0.64       460
#
# Training with: Epochs=5, Hidden Layer Size=128, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 13s 158ms/step - loss: 0.7170 - accuracy: 0.5457 - val_loss: 0.6656 - val_accuracy: 0.6109
# Epoch 2/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6488 - accuracy: 0.6120 - val_loss: 0.6382 - val_accuracy: 0.6130
# Epoch 3/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.6413 - accuracy: 0.6386 - val_loss: 0.6164 - val_accuracy: 0.6652
# Epoch 4/5
# 58/58 [==============================] - 8s 140ms/step - loss: 0.6058 - accuracy: 0.6652 - val_loss: 0.6266 - val_accuracy: 0.6674
# Epoch 5/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.5920 - accuracy: 0.6810 - val_loss: 0.5878 - val_accuracy: 0.7087
# 15/15 [==============================] - 2s 107ms/step - loss: 0.5878 - accuracy: 0.7087
# Last Validation Accuracy: 0.708695650100708
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 919ms/step
# F1 Score: 0.7086956521739132
# Precision: 0.7086956521739131
# Recall: 0.7086956521739131
# Confusion Matrix:
#  [[163  67]
#  [ 67 163]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.71      0.71      0.71       230
#     01-whole       0.71      0.71      0.71       230
#
#     accuracy                           0.71       460
#    macro avg       0.71      0.71      0.71       460
# weighted avg       0.71      0.71      0.71       460
#
# Training with: Epochs=5, Hidden Layer Size=128, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 13s 157ms/step - loss: 0.7144 - accuracy: 0.5413 - val_loss: 0.6797 - val_accuracy: 0.5261
# Epoch 2/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.6660 - accuracy: 0.6016 - val_loss: 0.6970 - val_accuracy: 0.5239
# Epoch 3/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.6458 - accuracy: 0.6239 - val_loss: 0.6424 - val_accuracy: 0.6261
# Epoch 4/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.6272 - accuracy: 0.6451 - val_loss: 0.6420 - val_accuracy: 0.6478
# Epoch 5/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.6156 - accuracy: 0.6630 - val_loss: 0.6176 - val_accuracy: 0.6826
# 15/15 [==============================] - 2s 104ms/step - loss: 0.6176 - accuracy: 0.6826
# Last Validation Accuracy: 0.6826087236404419
# 1/1 [==============================] - 1s 917ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 920ms/step
# F1 Score: 0.6825846944948578
# Precision: 0.6826639437258907
# Recall: 0.6826086956521739
# Confusion Matrix:
#  [[159  71]
#  [ 75 155]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.68      0.69      0.69       230
#     01-whole       0.69      0.67      0.68       230
#
#     accuracy                           0.68       460
#    macro avg       0.68      0.68      0.68       460
# weighted avg       0.68      0.68      0.68       460
#
# Training with: Epochs=5, Hidden Layer Size=256, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 13s 157ms/step - loss: 0.7797 - accuracy: 0.5457 - val_loss: 0.6615 - val_accuracy: 0.6109
# Epoch 2/5
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6547 - accuracy: 0.6049 - val_loss: 0.6364 - val_accuracy: 0.6500
# Epoch 3/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6346 - accuracy: 0.6380 - val_loss: 0.6212 - val_accuracy: 0.6609
# Epoch 4/5
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6098 - accuracy: 0.6766 - val_loss: 0.6441 - val_accuracy: 0.6500
# Epoch 5/5
# 58/58 [==============================] - 8s 145ms/step - loss: 0.5969 - accuracy: 0.6788 - val_loss: 0.5997 - val_accuracy: 0.6848
# 15/15 [==============================] - 2s 107ms/step - loss: 0.5997 - accuracy: 0.6848
# Last Validation Accuracy: 0.6847826242446899
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 926ms/step
# F1 Score: 0.6787570256849894
# Precision: 0.6997711062516605
# Recall: 0.6847826086956522
# Confusion Matrix:
#  [[189  41]
#  [104 126]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.65      0.82      0.72       230
#     01-whole       0.75      0.55      0.63       230
#
#     accuracy                           0.68       460
#    macro avg       0.70      0.68      0.68       460
# weighted avg       0.70      0.68      0.68       460
#
# Training with: Epochs=5, Hidden Layer Size=256, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 12s 157ms/step - loss: 0.8039 - accuracy: 0.5223 - val_loss: 0.6845 - val_accuracy: 0.5370
# Epoch 2/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.6552 - accuracy: 0.6065 - val_loss: 0.6538 - val_accuracy: 0.6261
# Epoch 3/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6582 - accuracy: 0.6190 - val_loss: 0.7154 - val_accuracy: 0.5283
# Epoch 4/5
# 58/58 [==============================] - 8s 134ms/step - loss: 0.6135 - accuracy: 0.6679 - val_loss: 0.6120 - val_accuracy: 0.6826
# Epoch 5/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.6318 - accuracy: 0.6467 - val_loss: 0.6029 - val_accuracy: 0.7087
# 15/15 [==============================] - 2s 103ms/step - loss: 0.6029 - accuracy: 0.7087
# Last Validation Accuracy: 0.708695650100708
# 1/1 [==============================] - 1s 902ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 1s 896ms/step
# F1 Score: 0.7086736237144585
# Precision: 0.7087587928295892
# Recall: 0.7086956521739131
# Confusion Matrix:
#  [[165  65]
#  [ 69 161]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.71      0.72      0.71       230
#     01-whole       0.71      0.70      0.71       230
#
#     accuracy                           0.71       460
#    macro avg       0.71      0.71      0.71       460
# weighted avg       0.71      0.71      0.71       460
#
# Training with: Epochs=5, Hidden Layer Size=256, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 13s 151ms/step - loss: 0.7149 - accuracy: 0.5326 - val_loss: 0.7077 - val_accuracy: 0.5000
# Epoch 2/5
# 58/58 [==============================] - 8s 140ms/step - loss: 0.6648 - accuracy: 0.5984 - val_loss: 0.6525 - val_accuracy: 0.5870
# Epoch 3/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.6393 - accuracy: 0.6397 - val_loss: 0.6328 - val_accuracy: 0.6543
# Epoch 4/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.6237 - accuracy: 0.6630 - val_loss: 0.6280 - val_accuracy: 0.6348
# Epoch 5/5
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6061 - accuracy: 0.6728 - val_loss: 0.6931 - val_accuracy: 0.5696
# 15/15 [==============================] - 2s 102ms/step - loss: 0.6931 - accuracy: 0.5696
# Last Validation Accuracy: 0.5695652365684509
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 907ms/step
# F1 Score: 0.5014778325123154
# Precision: 0.6533333333333334
# Recall: 0.5695652173913044
# Confusion Matrix:
#  [[216  14]
#  [184  46]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.54      0.94      0.69       230
#     01-whole       0.77      0.20      0.32       230
#
#     accuracy                           0.57       460
#    macro avg       0.65      0.57      0.50       460
# weighted avg       0.65      0.57      0.50       460
#
# Training with: Epochs=10, Hidden Layer Size=64, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 151ms/step - loss: 0.6870 - accuracy: 0.5620 - val_loss: 0.6752 - val_accuracy: 0.5391
# Epoch 2/10
# 58/58 [==============================] - 8s 142ms/step - loss: 0.6504 - accuracy: 0.6120 - val_loss: 0.6779 - val_accuracy: 0.5609
# Epoch 3/10
# 58/58 [==============================] - 8s 142ms/step - loss: 0.6347 - accuracy: 0.6223 - val_loss: 0.6344 - val_accuracy: 0.6370
# Epoch 4/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6217 - accuracy: 0.6484 - val_loss: 0.6208 - val_accuracy: 0.6609
# Epoch 5/10
# 58/58 [==============================] - 8s 140ms/step - loss: 0.6156 - accuracy: 0.6592 - val_loss: 0.6205 - val_accuracy: 0.6457
# Epoch 6/10
# 58/58 [==============================] - 8s 142ms/step - loss: 0.6000 - accuracy: 0.6772 - val_loss: 0.6476 - val_accuracy: 0.6522
# Epoch 7/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.5871 - accuracy: 0.6853 - val_loss: 0.6071 - val_accuracy: 0.6696
# Epoch 8/10
# 58/58 [==============================] - 8s 140ms/step - loss: 0.5902 - accuracy: 0.6832 - val_loss: 0.6191 - val_accuracy: 0.6717
# Epoch 9/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.5788 - accuracy: 0.7114 - val_loss: 0.5926 - val_accuracy: 0.6848
# Epoch 10/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.5798 - accuracy: 0.6924 - val_loss: 0.5986 - val_accuracy: 0.6674
# 15/15 [==============================] - 2s 104ms/step - loss: 0.5986 - accuracy: 0.6674
# Last Validation Accuracy: 0.667391300201416
# 1/1 [==============================] - 1s 927ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 938ms/step
# F1 Score: 0.6567482283858194
# Precision: 0.6910917369818079
# Recall: 0.6673913043478261
# Confusion Matrix:
#  [[194  36]
#  [117 113]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.62      0.84      0.72       230
#     01-whole       0.76      0.49      0.60       230
#
#     accuracy                           0.67       460
#    macro avg       0.69      0.67      0.66       460
# weighted avg       0.69      0.67      0.66       460
#
# Training with: Epochs=10, Hidden Layer Size=64, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 154ms/step - loss: 0.6903 - accuracy: 0.5679 - val_loss: 0.6562 - val_accuracy: 0.6196
# Epoch 2/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6515 - accuracy: 0.6217 - val_loss: 0.6325 - val_accuracy: 0.6761
# Epoch 3/10
# 58/58 [==============================] - 8s 137ms/step - loss: 0.6131 - accuracy: 0.6641 - val_loss: 0.6122 - val_accuracy: 0.6891
# Epoch 4/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6097 - accuracy: 0.6571 - val_loss: 0.6045 - val_accuracy: 0.6848
# Epoch 5/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.6037 - accuracy: 0.6636 - val_loss: 0.7144 - val_accuracy: 0.5674
# Epoch 6/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.5822 - accuracy: 0.6908 - val_loss: 0.6209 - val_accuracy: 0.6391
# Epoch 7/10
# 58/58 [==============================] - 8s 139ms/step - loss: 0.6199 - accuracy: 0.6533 - val_loss: 0.6058 - val_accuracy: 0.6783
# Epoch 8/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.5846 - accuracy: 0.6897 - val_loss: 0.5935 - val_accuracy: 0.6630
# Epoch 9/10
# 58/58 [==============================] - 8s 137ms/step - loss: 0.5592 - accuracy: 0.7103 - val_loss: 0.5688 - val_accuracy: 0.7087
# Epoch 10/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.5600 - accuracy: 0.7049 - val_loss: 0.5667 - val_accuracy: 0.7109
# 15/15 [==============================] - 2s 98ms/step - loss: 0.5667 - accuracy: 0.7109
# Last Validation Accuracy: 0.710869550704956
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 1s 887ms/step
# F1 Score: 0.7089867812073385
# Precision: 0.7164716384312355
# Recall: 0.7108695652173913
# Confusion Matrix:
#  [[145  85]
#  [ 48 182]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.75      0.63      0.69       230
#     01-whole       0.68      0.79      0.73       230
#
#     accuracy                           0.71       460
#    macro avg       0.72      0.71      0.71       460
# weighted avg       0.72      0.71      0.71       460
#
# Training with: Epochs=10, Hidden Layer Size=64, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 152ms/step - loss: 0.7153 - accuracy: 0.5011 - val_loss: 0.6809 - val_accuracy: 0.5370
# Epoch 2/10
# 58/58 [==============================] - 8s 144ms/step - loss: 0.6705 - accuracy: 0.5913 - val_loss: 0.6692 - val_accuracy: 0.6043
# Epoch 3/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6549 - accuracy: 0.6375 - val_loss: 0.6752 - val_accuracy: 0.5696
# Epoch 4/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.6450 - accuracy: 0.6109 - val_loss: 0.6509 - val_accuracy: 0.5913
# Epoch 5/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6224 - accuracy: 0.6717 - val_loss: 0.6614 - val_accuracy: 0.6087
# Epoch 6/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6137 - accuracy: 0.6717 - val_loss: 0.6196 - val_accuracy: 0.6609
# Epoch 7/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6067 - accuracy: 0.6799 - val_loss: 0.6214 - val_accuracy: 0.6522
# Epoch 8/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6306 - accuracy: 0.6435 - val_loss: 0.6798 - val_accuracy: 0.5717
# Epoch 9/10
# 58/58 [==============================] - 8s 137ms/step - loss: 0.5933 - accuracy: 0.6875 - val_loss: 0.6060 - val_accuracy: 0.6826
# Epoch 10/10
# 58/58 [==============================] - 8s 139ms/step - loss: 0.5850 - accuracy: 0.7054 - val_loss: 0.5966 - val_accuracy: 0.7022
# 15/15 [==============================] - 2s 105ms/step - loss: 0.5966 - accuracy: 0.7022
# Last Validation Accuracy: 0.7021738886833191
# 1/1 [==============================] - 1s 920ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 924ms/step
# F1 Score: 0.7021725055411415
# Precision: 0.7021777349288266
# Recall: 0.7021739130434783
# Confusion Matrix:
#  [[161  69]
#  [ 68 162]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.70      0.70      0.70       230
#     01-whole       0.70      0.70      0.70       230
#
#     accuracy                           0.70       460
#    macro avg       0.70      0.70      0.70       460
# weighted avg       0.70      0.70      0.70       460
#
# Training with: Epochs=10, Hidden Layer Size=128, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 149ms/step - loss: 0.7091 - accuracy: 0.5505 - val_loss: 0.6593 - val_accuracy: 0.6109
# Epoch 2/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6496 - accuracy: 0.6375 - val_loss: 0.6349 - val_accuracy: 0.6565
# Epoch 3/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6161 - accuracy: 0.6625 - val_loss: 0.6541 - val_accuracy: 0.6370
# Epoch 4/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6058 - accuracy: 0.6761 - val_loss: 0.6121 - val_accuracy: 0.6783
# Epoch 5/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.6030 - accuracy: 0.6853 - val_loss: 0.6134 - val_accuracy: 0.6435
# Epoch 6/10
# 58/58 [==============================] - 8s 140ms/step - loss: 0.5834 - accuracy: 0.6995 - val_loss: 0.5904 - val_accuracy: 0.6848
# Epoch 7/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5787 - accuracy: 0.6940 - val_loss: 0.5873 - val_accuracy: 0.6957
# Epoch 8/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5644 - accuracy: 0.7190 - val_loss: 0.7712 - val_accuracy: 0.5587
# Epoch 9/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.5702 - accuracy: 0.7033 - val_loss: 0.5743 - val_accuracy: 0.6957
# Epoch 10/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.5510 - accuracy: 0.7239 - val_loss: 0.6292 - val_accuracy: 0.6543
# 15/15 [==============================] - 2s 100ms/step - loss: 0.6292 - accuracy: 0.6543
# Last Validation Accuracy: 0.654347836971283
# 1/1 [==============================] - 1s 919ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 941ms/step
# F1 Score: 0.6258268489955032
# Precision: 0.7220499850425607
# Recall: 0.6543478260869565
# Confusion Matrix:
#  [[214  16]
#  [143  87]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.60      0.93      0.73       230
#     01-whole       0.84      0.38      0.52       230
#
#     accuracy                           0.65       460
#    macro avg       0.72      0.65      0.63       460
# weighted avg       0.72      0.65      0.63       460
#
# Training with: Epochs=10, Hidden Layer Size=128, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 13s 156ms/step - loss: 0.6990 - accuracy: 0.5533 - val_loss: 0.6701 - val_accuracy: 0.5630
# Epoch 2/10
# 58/58 [==============================] - 8s 141ms/step - loss: 0.6613 - accuracy: 0.6005 - val_loss: 0.6812 - val_accuracy: 0.5478
# Epoch 3/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6357 - accuracy: 0.6321 - val_loss: 0.6202 - val_accuracy: 0.6674
# Epoch 4/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.6273 - accuracy: 0.6462 - val_loss: 0.7669 - val_accuracy: 0.5239
# Epoch 5/10
# 58/58 [==============================] - 8s 137ms/step - loss: 0.6056 - accuracy: 0.6674 - val_loss: 0.5982 - val_accuracy: 0.6891
# Epoch 6/10
# 58/58 [==============================] - 8s 137ms/step - loss: 0.5835 - accuracy: 0.6967 - val_loss: 0.5834 - val_accuracy: 0.7109
# Epoch 7/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.5993 - accuracy: 0.6658 - val_loss: 0.5984 - val_accuracy: 0.6891
# Epoch 8/10
# 58/58 [==============================] - 8s 141ms/step - loss: 0.5758 - accuracy: 0.7000 - val_loss: 0.5788 - val_accuracy: 0.7000
# Epoch 9/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.5669 - accuracy: 0.7190 - val_loss: 0.5773 - val_accuracy: 0.6848
# Epoch 10/10
# 58/58 [==============================] - 8s 137ms/step - loss: 0.5492 - accuracy: 0.7332 - val_loss: 0.5673 - val_accuracy: 0.6978
# 15/15 [==============================] - 2s 105ms/step - loss: 0.5673 - accuracy: 0.6978
# Last Validation Accuracy: 0.697826087474823
# 1/1 [==============================] - 1s 908ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 887ms/step
# F1 Score: 0.6891151401996393
# Precision: 0.7227970449852037
# Recall: 0.6978260869565217
# Confusion Matrix:
#  [[199  31]
#  [108 122]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.65      0.87      0.74       230
#     01-whole       0.80      0.53      0.64       230
#
#     accuracy                           0.70       460
#    macro avg       0.72      0.70      0.69       460
# weighted avg       0.72      0.70      0.69       460
#
# Training with: Epochs=10, Hidden Layer Size=128, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 148ms/step - loss: 0.7091 - accuracy: 0.5473 - val_loss: 0.6712 - val_accuracy: 0.6109
# Epoch 2/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.6517 - accuracy: 0.6326 - val_loss: 0.6472 - val_accuracy: 0.6239
# Epoch 3/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6392 - accuracy: 0.6348 - val_loss: 0.6553 - val_accuracy: 0.5783
# Epoch 4/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6305 - accuracy: 0.6402 - val_loss: 0.6261 - val_accuracy: 0.6370
# Epoch 5/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6139 - accuracy: 0.6707 - val_loss: 0.6118 - val_accuracy: 0.6696
# Epoch 6/10
# 58/58 [==============================] - 8s 137ms/step - loss: 0.5919 - accuracy: 0.6973 - val_loss: 0.6344 - val_accuracy: 0.6609
# Epoch 7/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.6062 - accuracy: 0.6652 - val_loss: 0.6144 - val_accuracy: 0.6413
# Epoch 8/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6147 - accuracy: 0.6625 - val_loss: 0.6004 - val_accuracy: 0.6804
# Epoch 9/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.5738 - accuracy: 0.7103 - val_loss: 0.5953 - val_accuracy: 0.6870
# Epoch 10/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5864 - accuracy: 0.6853 - val_loss: 0.5923 - val_accuracy: 0.6935
# 15/15 [==============================] - 2s 105ms/step - loss: 0.5923 - accuracy: 0.6935
# Last Validation Accuracy: 0.6934782862663269
# 1/1 [==============================] - 1s 881ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 899ms/step
# F1 Score: 0.6886983983758177
# Precision: 0.7061388491671869
# Recall: 0.6934782608695652
# Confusion Matrix:
#  [[131  99]
#  [ 42 188]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.76      0.57      0.65       230
#     01-whole       0.66      0.82      0.73       230
#
#     accuracy                           0.69       460
#    macro avg       0.71      0.69      0.69       460
# weighted avg       0.71      0.69      0.69       460
#
# Training with: Epochs=10, Hidden Layer Size=256, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 13s 154ms/step - loss: 0.7364 - accuracy: 0.5326 - val_loss: 0.6989 - val_accuracy: 0.5174
# Epoch 2/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6912 - accuracy: 0.5701 - val_loss: 0.7229 - val_accuracy: 0.5391
# Epoch 3/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.6532 - accuracy: 0.6147 - val_loss: 0.6190 - val_accuracy: 0.6674
# Epoch 4/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.6076 - accuracy: 0.6717 - val_loss: 0.6125 - val_accuracy: 0.6717
# Epoch 5/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6183 - accuracy: 0.6527 - val_loss: 0.6039 - val_accuracy: 0.6913
# Epoch 6/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.5831 - accuracy: 0.7033 - val_loss: 0.6315 - val_accuracy: 0.6565
# Epoch 7/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.5887 - accuracy: 0.6815 - val_loss: 0.6053 - val_accuracy: 0.6783
# Epoch 8/10
# 58/58 [==============================] - 8s 137ms/step - loss: 0.5875 - accuracy: 0.6908 - val_loss: 0.6083 - val_accuracy: 0.6783
# Epoch 9/10
# 58/58 [==============================] - 8s 141ms/step - loss: 0.5617 - accuracy: 0.7207 - val_loss: 0.5721 - val_accuracy: 0.7109
# Epoch 10/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.5885 - accuracy: 0.6853 - val_loss: 0.5753 - val_accuracy: 0.7000
# 15/15 [==============================] - 2s 101ms/step - loss: 0.5753 - accuracy: 0.7000
# Last Validation Accuracy: 0.699999988079071
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 1s 952ms/step
# F1 Score: 0.6964131994261117
# Precision: 0.7099206349206348
# Recall: 0.7
# Confusion Matrix:
#  [[186  44]
#  [ 94 136]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.66      0.81      0.73       230
#     01-whole       0.76      0.59      0.66       230
#
#     accuracy                           0.70       460
#    macro avg       0.71      0.70      0.70       460
# weighted avg       0.71      0.70      0.70       460
#
# Training with: Epochs=10, Hidden Layer Size=256, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 152ms/step - loss: 0.8135 - accuracy: 0.5478 - val_loss: 0.6708 - val_accuracy: 0.5543
# Epoch 2/10
# 58/58 [==============================] - 8s 139ms/step - loss: 0.6512 - accuracy: 0.6272 - val_loss: 0.6641 - val_accuracy: 0.5739
# Epoch 3/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6259 - accuracy: 0.6571 - val_loss: 0.6239 - val_accuracy: 0.6565
# Epoch 4/10
# 58/58 [==============================] - 8s 139ms/step - loss: 0.6172 - accuracy: 0.6565 - val_loss: 0.6135 - val_accuracy: 0.6783
# Epoch 5/10
# 58/58 [==============================] - 8s 137ms/step - loss: 0.5960 - accuracy: 0.6821 - val_loss: 0.5965 - val_accuracy: 0.6870
# Epoch 6/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.6285 - accuracy: 0.6571 - val_loss: 0.6225 - val_accuracy: 0.6609
# Epoch 7/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.5772 - accuracy: 0.6870 - val_loss: 0.5780 - val_accuracy: 0.7043
# Epoch 8/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.5739 - accuracy: 0.7005 - val_loss: 0.5747 - val_accuracy: 0.6870
# Epoch 9/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.5685 - accuracy: 0.6984 - val_loss: 0.5676 - val_accuracy: 0.7022
# Epoch 10/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5699 - accuracy: 0.6924 - val_loss: 0.5620 - val_accuracy: 0.7087
# 15/15 [==============================] - 2s 104ms/step - loss: 0.5620 - accuracy: 0.7087
# Last Validation Accuracy: 0.708695650100708
# 1/1 [==============================] - 1s 954ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 1s 924ms/step
# F1 Score: 0.7082489255760238
# Precision: 0.7099817407181984
# Recall: 0.7086956521739131
# Confusion Matrix:
#  [[172  58]
#  [ 76 154]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.69      0.75      0.72       230
#     01-whole       0.73      0.67      0.70       230
#
#     accuracy                           0.71       460
#    macro avg       0.71      0.71      0.71       460
# weighted avg       0.71      0.71      0.71       460
#
# Training with: Epochs=10, Hidden Layer Size=256, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 152ms/step - loss: 0.6989 - accuracy: 0.5543 - val_loss: 0.6650 - val_accuracy: 0.6065
# Epoch 2/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6645 - accuracy: 0.6005 - val_loss: 0.6677 - val_accuracy: 0.5870
# Epoch 3/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6394 - accuracy: 0.6277 - val_loss: 0.6252 - val_accuracy: 0.6826
# Epoch 4/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6113 - accuracy: 0.6815 - val_loss: 0.6164 - val_accuracy: 0.6630
# Epoch 5/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.5948 - accuracy: 0.6918 - val_loss: 0.6133 - val_accuracy: 0.6696
# Epoch 6/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6049 - accuracy: 0.6614 - val_loss: 0.6158 - val_accuracy: 0.6739
# Epoch 7/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.6022 - accuracy: 0.6712 - val_loss: 0.6578 - val_accuracy: 0.6391
# Epoch 8/10
# 58/58 [==============================] - 8s 138ms/step - loss: 0.5888 - accuracy: 0.6940 - val_loss: 0.5847 - val_accuracy: 0.7022
# Epoch 9/10
# 58/58 [==============================] - 8s 128ms/step - loss: 0.5671 - accuracy: 0.7098 - val_loss: 0.6078 - val_accuracy: 0.6522
# Epoch 10/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.5580 - accuracy: 0.7054 - val_loss: 0.5733 - val_accuracy: 0.7065
# 15/15 [==============================] - 2s 102ms/step - loss: 0.5733 - accuracy: 0.7065
# Last Validation Accuracy: 0.70652174949646
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 1s 942ms/step
# F1 Score: 0.7051828009058152
# Precision: 0.7103429022507172
# Recall: 0.7065217391304348
# Confusion Matrix:
#  [[147  83]
#  [ 52 178]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.74      0.64      0.69       230
#     01-whole       0.68      0.77      0.73       230
#
#     accuracy                           0.71       460
#    macro avg       0.71      0.71      0.71       460
# weighted avg       0.71      0.71      0.71       460
#
# Training with: Epochs=15, Hidden Layer Size=64, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 12s 151ms/step - loss: 0.6952 - accuracy: 0.5435 - val_loss: 0.6646 - val_accuracy: 0.5957
# Epoch 2/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.6635 - accuracy: 0.5913 - val_loss: 0.6541 - val_accuracy: 0.6261
# Epoch 3/15
# 58/58 [==============================] - 8s 144ms/step - loss: 0.6318 - accuracy: 0.6549 - val_loss: 0.6825 - val_accuracy: 0.5630
# Epoch 4/15
# 58/58 [==============================] - 8s 139ms/step - loss: 0.6202 - accuracy: 0.6598 - val_loss: 0.6192 - val_accuracy: 0.6717
# Epoch 5/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.6023 - accuracy: 0.6793 - val_loss: 0.6113 - val_accuracy: 0.6717
# Epoch 6/15
# ...
# 1/1 [==============================] - 1s 944ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 1s 929ms/step
# F1 Score: 0.7390070921985814
# Precision: 0.7395833333333333
# Recall: 0.7391304347826086
# Confusion Matrix:
#  [[165  65]
#  [ 55 175]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.75      0.72      0.73       230
#     01-whole       0.73      0.76      0.74       230
#
#     accuracy                           0.74       460
#    macro avg       0.74      0.74      0.74       460
# weighted avg       0.74      0.74      0.74       460
#
# Training with: Epochs=15, Hidden Layer Size=128, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 12s 157ms/step - loss: 0.6955 - accuracy: 0.5380 - val_loss: 0.6708 - val_accuracy: 0.6000
# Epoch 2/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6729 - accuracy: 0.5755 - val_loss: 0.6512 - val_accuracy: 0.6370
# Epoch 3/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.6403 - accuracy: 0.6342 - val_loss: 0.6350 - val_accuracy: 0.6500
# Epoch 4/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6271 - accuracy: 0.6495 - val_loss: 0.6259 - val_accuracy: 0.6478
# Epoch 5/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.6127 - accuracy: 0.6614 - val_loss: 0.6209 - val_accuracy: 0.6609
# Epoch 6/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6157 - accuracy: 0.6587 - val_loss: 0.6382 - val_accuracy: 0.6065
# Epoch 7/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5899 - accuracy: 0.7043 - val_loss: 0.5986 - val_accuracy: 0.6870
# Epoch 8/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.5803 - accuracy: 0.7022 - val_loss: 0.5992 - val_accuracy: 0.6761
# Epoch 9/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.5680 - accuracy: 0.7147 - val_loss: 0.5901 - val_accuracy: 0.6957
# Epoch 10/15
# 58/58 [==============================] - 8s 137ms/step - loss: 0.5664 - accuracy: 0.7076 - val_loss: 0.5898 - val_accuracy: 0.6783
# Epoch 11/15
# 58/58 [==============================] - 8s 137ms/step - loss: 0.5602 - accuracy: 0.7022 - val_loss: 0.5758 - val_accuracy: 0.7000
# Epoch 12/15
# 58/58 [==============================] - 8s 138ms/step - loss: 0.5844 - accuracy: 0.6989 - val_loss: 0.5772 - val_accuracy: 0.7022
# Epoch 13/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5480 - accuracy: 0.7321 - val_loss: 0.5631 - val_accuracy: 0.7174
# Epoch 14/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.5528 - accuracy: 0.7190 - val_loss: 0.5602 - val_accuracy: 0.7174
# Epoch 15/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.5556 - accuracy: 0.7087 - val_loss: 0.5647 - val_accuracy: 0.7087
# 15/15 [==============================] - 2s 99ms/step - loss: 0.5647 - accuracy: 0.7087
# Last Validation Accuracy: 0.708695650100708
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 1s 890ms/step
# F1 Score: 0.7052128168340507
# Precision: 0.719047619047619
# Recall: 0.7086956521739131
# Confusion Matrix:
#  [[188  42]
#  [ 92 138]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.67      0.82      0.74       230
#     01-whole       0.77      0.60      0.67       230
#
#     accuracy                           0.71       460
#    macro avg       0.72      0.71      0.71       460
# weighted avg       0.72      0.71      0.71       460
#
# Training with: Epochs=15, Hidden Layer Size=256, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 12s 155ms/step - loss: 0.7484 - accuracy: 0.5435 - val_loss: 0.6697 - val_accuracy: 0.5891
# Epoch 2/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6518 - accuracy: 0.6152 - val_loss: 0.6372 - val_accuracy: 0.6522
# Epoch 3/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.6260 - accuracy: 0.6446 - val_loss: 0.6649 - val_accuracy: 0.5739
# Epoch 4/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.6182 - accuracy: 0.6582 - val_loss: 0.7139 - val_accuracy: 0.5609
# Epoch 5/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5931 - accuracy: 0.6821 - val_loss: 0.6028 - val_accuracy: 0.6761
# Epoch 6/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.6027 - accuracy: 0.6755 - val_loss: 0.5957 - val_accuracy: 0.6891
# Epoch 7/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.5932 - accuracy: 0.6745 - val_loss: 0.6030 - val_accuracy: 0.6543
# Epoch 8/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.5814 - accuracy: 0.6891 - val_loss: 0.6010 - val_accuracy: 0.6870
# Epoch 9/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.5666 - accuracy: 0.7087 - val_loss: 0.5740 - val_accuracy: 0.7065
# Epoch 10/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.5636 - accuracy: 0.7076 - val_loss: 0.5660 - val_accuracy: 0.7109
# Epoch 11/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.5565 - accuracy: 0.7136 - val_loss: 0.5555 - val_accuracy: 0.7152
# Epoch 12/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.5401 - accuracy: 0.7353 - val_loss: 0.5573 - val_accuracy: 0.7217
# Epoch 13/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.5594 - accuracy: 0.7190 - val_loss: 0.5510 - val_accuracy: 0.7304
# Epoch 14/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.5379 - accuracy: 0.7364 - val_loss: 0.5742 - val_accuracy: 0.7043
# Epoch 15/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.5277 - accuracy: 0.7424 - val_loss: 0.5571 - val_accuracy: 0.7130
# 15/15 [==============================] - 2s 106ms/step - loss: 0.5571 - accuracy: 0.7130
# Last Validation Accuracy: 0.7130434513092041
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 907ms/step
# F1 Score: 0.704990671641791
# Precision: 0.7391562685680333
# Recall: 0.7130434782608696
# Confusion Matrix:
#  [[202  28]
#  [104 126]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.66      0.88      0.75       230
#     01-whole       0.82      0.55      0.66       230
#
#     accuracy                           0.71       460
#    macro avg       0.74      0.71      0.70       460
# weighted avg       0.74      0.71      0.70       460
#
# Training with: Epochs=15, Hidden Layer Size=256, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 12s 149ms/step - loss: 0.7077 - accuracy: 0.5652 - val_loss: 0.7069 - val_accuracy: 0.5370
# Epoch 2/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.6574 - accuracy: 0.5924 - val_loss: 0.6976 - val_accuracy: 0.5543
# Epoch 3/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.6169 - accuracy: 0.6554 - val_loss: 0.6402 - val_accuracy: 0.6109
# Epoch 4/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.6129 - accuracy: 0.6641 - val_loss: 0.5959 - val_accuracy: 0.7065
# Epoch 5/15
# 58/58 [==============================] - 8s 129ms/step - loss: 0.5694 - accuracy: 0.7087 - val_loss: 0.6694 - val_accuracy: 0.6326
# Epoch 6/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.5936 - accuracy: 0.6783 - val_loss: 0.5731 - val_accuracy: 0.7087
# Epoch 7/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5660 - accuracy: 0.7043 - val_loss: 0.6099 - val_accuracy: 0.6522
# Epoch 8/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.5794 - accuracy: 0.7033 - val_loss: 0.5732 - val_accuracy: 0.6978
# Epoch 9/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5352 - accuracy: 0.7293 - val_loss: 0.5762 - val_accuracy: 0.7000
# Epoch 10/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.5385 - accuracy: 0.7321 - val_loss: 0.5380 - val_accuracy: 0.7304
# Epoch 11/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.5242 - accuracy: 0.7489 - val_loss: 0.5509 - val_accuracy: 0.7174
# Epoch 12/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.5160 - accuracy: 0.7418 - val_loss: 0.5385 - val_accuracy: 0.7283
# Epoch 13/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.5308 - accuracy: 0.7321 - val_loss: 0.5892 - val_accuracy: 0.6913
# Epoch 14/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.5241 - accuracy: 0.7364 - val_loss: 0.5224 - val_accuracy: 0.7370
# Epoch 15/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.5425 - accuracy: 0.7228 - val_loss: 0.7479 - val_accuracy: 0.5783
# 15/15 [==============================] - 2s 101ms/step - loss: 0.7479 - accuracy: 0.5783
# Last Validation Accuracy: 0.5782608985900879
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 2s 2s/step
# F1 Score: 0.49369099491648505
# Precision: 0.7358168147641831
# Recall: 0.5782608695652174
# Confusion Matrix:
#  [[ 39 191]
#  [  3 227]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.93      0.17      0.29       230
#     01-whole       0.54      0.99      0.70       230
#
#     accuracy                           0.58       460
#    macro avg       0.74      0.58      0.49       460
# weighted avg       0.74      0.58      0.49       460
#
# Training with: Epochs=15, Hidden Layer Size=256, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 12s 151ms/step - loss: 0.6910 - accuracy: 0.5348 - val_loss: 0.6746 - val_accuracy: 0.5413
# Epoch 2/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.6505 - accuracy: 0.6163 - val_loss: 0.6826 - val_accuracy: 0.5587
# Epoch 3/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.6455 - accuracy: 0.6136 - val_loss: 0.6297 - val_accuracy: 0.6261
# Epoch 4/15
# 58/58 [==============================] - 8s 129ms/step - loss: 0.6091 - accuracy: 0.6777 - val_loss: 0.6203 - val_accuracy: 0.6457
# Epoch 5/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.6080 - accuracy: 0.6668 - val_loss: 0.6125 - val_accuracy: 0.6413
# Epoch 6/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.6178 - accuracy: 0.6560 - val_loss: 0.6056 - val_accuracy: 0.6696
# Epoch 7/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.5828 - accuracy: 0.7016 - val_loss: 0.6313 - val_accuracy: 0.6326
# Epoch 8/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.5717 - accuracy: 0.7130 - val_loss: 0.5841 - val_accuracy: 0.6978
# Epoch 9/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.5672 - accuracy: 0.7114 - val_loss: 0.5781 - val_accuracy: 0.6957
# Epoch 10/15
# 58/58 [==============================] - 8s 129ms/step - loss: 0.5820 - accuracy: 0.6962 - val_loss: 0.5826 - val_accuracy: 0.6783
# Epoch 11/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.5668 - accuracy: 0.7092 - val_loss: 0.7008 - val_accuracy: 0.6000
# Epoch 12/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.5685 - accuracy: 0.6902 - val_loss: 0.5780 - val_accuracy: 0.6935
# Epoch 13/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.5382 - accuracy: 0.7386 - val_loss: 0.5749 - val_accuracy: 0.6957
# Epoch 14/15
# 58/58 [==============================] - 8s 138ms/step - loss: 0.5286 - accuracy: 0.7424 - val_loss: 0.5490 - val_accuracy: 0.7022
# Epoch 15/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.5435 - accuracy: 0.7185 - val_loss: 0.5686 - val_accuracy: 0.7043
# 15/15 [==============================] - 2s 94ms/step - loss: 0.5686 - accuracy: 0.7043
# Last Validation Accuracy: 0.7043478488922119
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 1s 901ms/step
# F1 Score: 0.6955954767512018
# Precision: 0.730903964456596
# Recall: 0.7043478260869566
# Confusion Matrix:
#  [[123 107]
#  [ 29 201]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.81      0.53      0.64       230
#     01-whole       0.65      0.87      0.75       230
#
#     accuracy                           0.70       460
#    macro avg       0.73      0.70      0.70       460
# weighted avg       0.73      0.70      0.70       460

# %%
# Print the best hyperparameters and the best validation accuracy
print("Best Hyperparameters: ", best_params)
print("Best Validation Accuracy: ", best_score)

# Create a DataFrame from the results list
df = pd.DataFrame(results)

# Group the DataFrame by the 'Activation' column
grouped = df.groupby('Activation')

# Print the grouped DataFrame
for name, group in grouped:
    print(name)
    print(group)
# Out:
# Best Hyperparameters:  {'epochs': 15, 'hidden_layer_size': 128, 'activation': 'tanh'}
# Best Validation Accuracy:  0.739130437374115
# relu
#     Epochs  Hidden Layer Size Activation  Validation Accuracy
# 0        5                 64       relu             0.639130
# 3        5                128       relu             0.654348
# 6        5                256       relu             0.684783
# 9       10                 64       relu             0.667391
# 12      10                128       relu             0.654348
# 15      10                256       relu             0.700000
# 18      15                 64       relu             0.728261
# 21      15                128       relu             0.732609
# 24      15                256       relu             0.713043
# sigmoid
#     Epochs  Hidden Layer Size Activation  Validation Accuracy
# 2        5                 64    sigmoid             0.647826
# 5        5                128    sigmoid             0.682609
# 8        5                256    sigmoid             0.569565
# 11      10                 64    sigmoid             0.702174
# 14      10                128    sigmoid             0.693478
# 17      10                256    sigmoid             0.706522
# 20      15                 64    sigmoid             0.717391
# 23      15                128    sigmoid             0.708696
# 26      15                256    sigmoid             0.704348
# tanh
#     Epochs  Hidden Layer Size Activation  Validation Accuracy
# 1        5                 64       tanh             0.569565
# 4        5                128       tanh             0.708696
# 7        5                256       tanh             0.708696
# 10      10                 64       tanh             0.710870
# 13      10                128       tanh             0.697826
# 16      10                256       tanh             0.708696
# 19      15                 64       tanh             0.697826
# 22      15                128       tanh             0.739130
# 25      15                256       tanh             0.578261
