# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define a function to create the model with specified hyperparameters
def create_model(epochs, hidden_layer_size, activation):
    img_height, img_width = 224, 224
    batch_size = 32

    # Load VGG16 with pre-trained weights
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Freeze all layers in the base model
    for layer in base_model.layers:
        layer.trainable = False

    # Add custom layers with convolutional layers and max-pooling
    model = Sequential([
        base_model,

        GlobalAveragePooling2D(),

        Dense(hidden_layer_size, activation=activation),
        Dense(2, activation='softmax')  # Softmax for multi-class classification
    ])

    # Data Generators
    train_datagen = ImageDataGenerator(rescale=1./255)
    train_gen = train_datagen.flow_from_directory(
        '/content/drive/MyDrive/DataSet Grad Project/dataset_1/training',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    val_datagen = ImageDataGenerator(rescale=1./255)
    val_gen = val_datagen.flow_from_directory(
        '/content/drive/MyDrive/DataSet Grad Project/dataset_1/validation',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compile the model with categorical cross-entropy and the metric 'accuracy'
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Training the model
    history = model.fit(train_gen, epochs=epochs, validation_data=val_gen)

    # Evaluate the model
    evaluation = model.evaluate(val_gen)
    val_accuracy = evaluation[1]
    print(f"Last Validation Accuracy: {val_accuracy}")

    return history, val_accuracy,val_gen,train_gen,model

# Define the hyperparameter values for the grid search
epochs_values = [5, 10, 15]
hidden_layer_sizes = [64, 128, 256]
activations = ['relu', 'tanh', 'sigmoid']

# %%
# Define an empty list to store the results
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score
results = []

# Initialize best_score and best_params
best_score = 0.0
best_params = {}


# Perform grid search
for epochs in epochs_values:
    for hidden_layer_size in hidden_layer_sizes:
        for activation in activations:
            print(f"Training with: Epochs={epochs}, Hidden Layer Size={hidden_layer_size}, Activation={activation}")
            history, val_accuracy,val_gen,train_gen,model = create_model(epochs, hidden_layer_size, activation)
            class_labels = train_gen.class_indices

            class_labels = {v: k for k, v in class_labels.items()}

            true_labels = []
            predicted_classes = []

            for i in range(len(val_gen)):
                batch_images, batch_labels = next(val_gen)
                true_labels.extend(batch_labels.argmax(axis=1))
                predicted_classes.extend(model.predict(batch_images).argmax(axis=1))

            # Calculate the F1 score, precision, recall, and confusion matrix
            f1_score_value = f1_score(true_labels, predicted_classes, average='weighted')
            precision = precision_score(true_labels, predicted_classes, average='weighted')
            recall = recall_score(true_labels, predicted_classes, average='weighted')
            conf_matrix = confusion_matrix(true_labels, predicted_classes)

            print("F1 Score:", f1_score_value)
            print("Precision:", precision)
            print("Recall:", recall)
            print("Confusion Matrix:\n", conf_matrix)

            # Generate a classification report
            report = classification_report(true_labels, predicted_classes, target_names=class_labels.values())

            print("Classification Report:\n", report)


            result = {
                'Epochs': epochs,
                'Hidden Layer Size': hidden_layer_size,
                'Activation': activation,
                'Validation Accuracy': val_accuracy
            }
            results.append(result)

            # Update best hyperparameters and best score
            if val_accuracy > best_score:
                best_score = val_accuracy
                best_params = {
                    'epochs': epochs,
                    'hidden_layer_size': hidden_layer_size,
                    'activation': activation
                }
# Out:
# Training with: Epochs=5, Hidden Layer Size=64, Activation=relu
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 505s 9s/step - loss: 0.3199 - accuracy: 0.8652 - val_loss: 0.2145 - val_accuracy: 0.9130
# Epoch 2/5
# 58/58 [==============================] - 8s 142ms/step - loss: 0.1826 - accuracy: 0.9245 - val_loss: 0.2069 - val_accuracy: 0.9261
# Epoch 3/5
# 58/58 [==============================] - 8s 141ms/step - loss: 0.1609 - accuracy: 0.9337 - val_loss: 0.2800 - val_accuracy: 0.8696
# Epoch 4/5
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1190 - accuracy: 0.9533 - val_loss: 0.1996 - val_accuracy: 0.9174
# Epoch 5/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0933 - accuracy: 0.9587 - val_loss: 0.1996 - val_accuracy: 0.9130
# 15/15 [==============================] - 2s 102ms/step - loss: 0.1996 - accuracy: 0.9130
# Last Validation Accuracy: 0.9130434989929199
# 1/1 [==============================] - 1s 816ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 1s 751ms/step
# F1 Score: 0.9130171696543378
# Precision: 0.9135437958967371
# Recall: 0.9130434782608695
# Confusion Matrix:
#  [[206  24]
#  [ 16 214]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.93      0.90      0.91       230
#     01-whole       0.90      0.93      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
# Training with: Epochs=5, Hidden Layer Size=64, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 11s 142ms/step - loss: 0.3525 - accuracy: 0.8451 - val_loss: 0.1951 - val_accuracy: 0.9283
# Epoch 2/5
# 58/58 [==============================] - 8s 137ms/step - loss: 0.1881 - accuracy: 0.9266 - val_loss: 0.1979 - val_accuracy: 0.9239
# Epoch 3/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1427 - accuracy: 0.9424 - val_loss: 0.2102 - val_accuracy: 0.9152
# Epoch 4/5
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1132 - accuracy: 0.9576 - val_loss: 0.1971 - val_accuracy: 0.9261
# Epoch 5/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0852 - accuracy: 0.9712 - val_loss: 0.2012 - val_accuracy: 0.9217
# 15/15 [==============================] - 2s 98ms/step - loss: 0.2012 - accuracy: 0.9217
# Last Validation Accuracy: 0.9217391014099121
# 1/1 [==============================] - 1s 779ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 1s 738ms/step
# F1 Score: 0.9217332123411979
# Precision: 0.9218667271764616
# Recall: 0.9217391304347826
# Confusion Matrix:
#  [[214  16]
#  [ 20 210]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.91      0.93      0.92       230
#     01-whole       0.93      0.91      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=5, Hidden Layer Size=64, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 11s 141ms/step - loss: 0.3241 - accuracy: 0.8668 - val_loss: 0.2201 - val_accuracy: 0.9326
# Epoch 2/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2051 - accuracy: 0.9190 - val_loss: 0.2010 - val_accuracy: 0.9348
# Epoch 3/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1734 - accuracy: 0.9321 - val_loss: 0.2098 - val_accuracy: 0.9217
# Epoch 4/5
# 58/58 [==============================] - 7s 128ms/step - loss: 0.1518 - accuracy: 0.9397 - val_loss: 0.1939 - val_accuracy: 0.9261
# Epoch 5/5
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1286 - accuracy: 0.9516 - val_loss: 0.2032 - val_accuracy: 0.9152
# 15/15 [==============================] - 2s 102ms/step - loss: 0.2032 - accuracy: 0.9152
# Last Validation Accuracy: 0.915217399597168
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 722ms/step
# F1 Score: 0.9151496232813543
# Precision: 0.9165481405624776
# Recall: 0.9152173913043479
# Confusion Matrix:
#  [[204  26]
#  [ 13 217]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.94      0.89      0.91       230
#     01-whole       0.89      0.94      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=5, Hidden Layer Size=128, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 11s 142ms/step - loss: 0.3703 - accuracy: 0.8402 - val_loss: 0.2154 - val_accuracy: 0.9326
# Epoch 2/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1972 - accuracy: 0.9082 - val_loss: 0.2128 - val_accuracy: 0.9261
# Epoch 3/5
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1421 - accuracy: 0.9467 - val_loss: 0.2213 - val_accuracy: 0.9174
# Epoch 4/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1194 - accuracy: 0.9511 - val_loss: 0.2135 - val_accuracy: 0.9239
# Epoch 5/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0932 - accuracy: 0.9641 - val_loss: 0.2104 - val_accuracy: 0.9217
# 15/15 [==============================] - 2s 103ms/step - loss: 0.2104 - accuracy: 0.9217
# Last Validation Accuracy: 0.9217391014099121
# 1/1 [==============================] - 1s 831ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 1s 755ms/step
# F1 Score: 0.9217376509952929
# Precision: 0.921771022383545
# Recall: 0.9217391304347826
# Confusion Matrix:
#  [[213  17]
#  [ 19 211]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.92      0.93      0.92       230
#     01-whole       0.93      0.92      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=5, Hidden Layer Size=128, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 11s 147ms/step - loss: 0.3238 - accuracy: 0.8576 - val_loss: 0.2118 - val_accuracy: 0.9283
# Epoch 2/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1850 - accuracy: 0.9255 - val_loss: 0.2039 - val_accuracy: 0.9239
# Epoch 3/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.1257 - accuracy: 0.9538 - val_loss: 0.2092 - val_accuracy: 0.9152
# Epoch 4/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0974 - accuracy: 0.9663 - val_loss: 0.2295 - val_accuracy: 0.9174
# Epoch 5/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0705 - accuracy: 0.9772 - val_loss: 0.2437 - val_accuracy: 0.9109
# 15/15 [==============================] - 2s 101ms/step - loss: 0.2437 - accuracy: 0.9109
# Last Validation Accuracy: 0.9108695387840271
# 1/1 [==============================] - 1s 727ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 1s 746ms/step
# F1 Score: 0.910646180669064
# Precision: 0.9150197628458497
# Recall: 0.9108695652173913
# Confusion Matrix:
#  [[198  32]
#  [  9 221]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.96      0.86      0.91       230
#     01-whole       0.87      0.96      0.92       230
#
#     accuracy                           0.91       460
#    macro avg       0.92      0.91      0.91       460
# weighted avg       0.92      0.91      0.91       460
#
# Training with: Epochs=5, Hidden Layer Size=128, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 12s 153ms/step - loss: 0.3635 - accuracy: 0.8353 - val_loss: 0.2271 - val_accuracy: 0.9174
# Epoch 2/5
# 58/58 [==============================] - 7s 127ms/step - loss: 0.2130 - accuracy: 0.9120 - val_loss: 0.2113 - val_accuracy: 0.9196
# Epoch 3/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1691 - accuracy: 0.9375 - val_loss: 0.2024 - val_accuracy: 0.9261
# Epoch 4/5
# 58/58 [==============================] - 8s 129ms/step - loss: 0.1407 - accuracy: 0.9478 - val_loss: 0.2183 - val_accuracy: 0.9130
# Epoch 5/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.1262 - accuracy: 0.9549 - val_loss: 0.2009 - val_accuracy: 0.9239
# 15/15 [==============================] - 2s 102ms/step - loss: 0.2009 - accuracy: 0.9239
# Last Validation Accuracy: 0.9239130616188049
# 1/1 [==============================] - 1s 748ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 783ms/step
# F1 Score: 0.9238522260217281
# Precision: 0.9252716618308016
# Recall: 0.9239130434782609
# Confusion Matrix:
#  [[219  11]
#  [ 24 206]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.90      0.95      0.93       230
#     01-whole       0.95      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.93      0.92      0.92       460
# weighted avg       0.93      0.92      0.92       460
#
# Training with: Epochs=5, Hidden Layer Size=256, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 11s 143ms/step - loss: 0.4177 - accuracy: 0.8337 - val_loss: 0.2038 - val_accuracy: 0.9413
# Epoch 2/5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2054 - accuracy: 0.9136 - val_loss: 0.2140 - val_accuracy: 0.9326
# Epoch 3/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.1428 - accuracy: 0.9380 - val_loss: 0.2002 - val_accuracy: 0.9174
# Epoch 4/5
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1136 - accuracy: 0.9582 - val_loss: 0.2288 - val_accuracy: 0.9087
# Epoch 5/5
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0869 - accuracy: 0.9696 - val_loss: 0.2209 - val_accuracy: 0.9261
# 15/15 [==============================] - 2s 100ms/step - loss: 0.2209 - accuracy: 0.9261
# Last Validation Accuracy: 0.926086962223053
# 1/1 [==============================] - 1s 738ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 761ms/step
# F1 Score: 0.925997425997426
# Precision: 0.9281589544867411
# Recall: 0.9260869565217391
# Confusion Matrix:
#  [[221   9]
#  [ 25 205]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.90      0.96      0.93       230
#     01-whole       0.96      0.89      0.92       230
#
#     accuracy                           0.93       460
#    macro avg       0.93      0.93      0.93       460
# weighted avg       0.93      0.93      0.93       460
#
# Training with: Epochs=5, Hidden Layer Size=256, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 12s 153ms/step - loss: 0.4672 - accuracy: 0.8277 - val_loss: 0.2067 - val_accuracy: 0.9152
# Epoch 2/5
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1774 - accuracy: 0.9272 - val_loss: 0.2136 - val_accuracy: 0.9217
# Epoch 3/5
# 58/58 [==============================] - 8s 135ms/step - loss: 0.1460 - accuracy: 0.9380 - val_loss: 0.2487 - val_accuracy: 0.9065
# Epoch 4/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1059 - accuracy: 0.9630 - val_loss: 0.2092 - val_accuracy: 0.9261
# Epoch 5/5
# 58/58 [==============================] - 7s 128ms/step - loss: 0.0770 - accuracy: 0.9739 - val_loss: 0.2199 - val_accuracy: 0.9239
# 15/15 [==============================] - 2s 99ms/step - loss: 0.2199 - accuracy: 0.9239
# Last Validation Accuracy: 0.9239130616188049
# 1/1 [==============================] - 1s 810ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 1s 751ms/step
# F1 Score: 0.9238695095021255
# Precision: 0.924884897402376
# Recall: 0.9239130434782609
# Confusion Matrix:
#  [[218  12]
#  [ 23 207]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.90      0.95      0.93       230
#     01-whole       0.95      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=5, Hidden Layer Size=256, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/5
# 58/58 [==============================] - 11s 144ms/step - loss: 0.2951 - accuracy: 0.8788 - val_loss: 0.2137 - val_accuracy: 0.9174
# Epoch 2/5
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2029 - accuracy: 0.9158 - val_loss: 0.1938 - val_accuracy: 0.9283
# Epoch 3/5
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1446 - accuracy: 0.9478 - val_loss: 0.1940 - val_accuracy: 0.9283
# Epoch 4/5
# 58/58 [==============================] - 7s 128ms/step - loss: 0.1256 - accuracy: 0.9511 - val_loss: 0.2133 - val_accuracy: 0.9152
# Epoch 5/5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1107 - accuracy: 0.9565 - val_loss: 0.2211 - val_accuracy: 0.9152
# 15/15 [==============================] - 2s 101ms/step - loss: 0.2211 - accuracy: 0.9152
# Last Validation Accuracy: 0.915217399597168
# 1/1 [==============================] - 1s 740ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 1s 727ms/step
# F1 Score: 0.9151271437019516
# Precision: 0.9169909824394874
# Recall: 0.9152173913043479
# Confusion Matrix:
#  [[203  27]
#  [ 12 218]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.94      0.88      0.91       230
#     01-whole       0.89      0.95      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=64, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 155ms/step - loss: 0.3373 - accuracy: 0.8533 - val_loss: 0.2204 - val_accuracy: 0.9239
# Epoch 2/10
# 58/58 [==============================] - 7s 126ms/step - loss: 0.1888 - accuracy: 0.9207 - val_loss: 0.1899 - val_accuracy: 0.9326
# Epoch 3/10
# 58/58 [==============================] - 7s 128ms/step - loss: 0.1587 - accuracy: 0.9321 - val_loss: 0.1937 - val_accuracy: 0.9239
# Epoch 4/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1167 - accuracy: 0.9505 - val_loss: 0.2152 - val_accuracy: 0.9217
# Epoch 5/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0917 - accuracy: 0.9696 - val_loss: 0.1988 - val_accuracy: 0.9283
# Epoch 6/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0715 - accuracy: 0.9750 - val_loss: 0.1948 - val_accuracy: 0.9217
# Epoch 7/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0520 - accuracy: 0.9815 - val_loss: 0.2077 - val_accuracy: 0.9283
# Epoch 8/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0358 - accuracy: 0.9946 - val_loss: 0.2246 - val_accuracy: 0.9217
# Epoch 9/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0253 - accuracy: 0.9967 - val_loss: 0.2239 - val_accuracy: 0.9304
# Epoch 10/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0226 - accuracy: 0.9978 - val_loss: 0.2508 - val_accuracy: 0.9022
# 15/15 [==============================] - 2s 100ms/step - loss: 0.2508 - accuracy: 0.9022
# Last Validation Accuracy: 0.9021739363670349
# 1/1 [==============================] - 1s 790ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 739ms/step
# F1 Score: 0.9021364510989557
# Precision: 0.9027906624510119
# Recall: 0.9021739130434783
# Confusion Matrix:
#  [[203  27]
#  [ 18 212]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.92      0.88      0.90       230
#     01-whole       0.89      0.92      0.90       230
#
#     accuracy                           0.90       460
#    macro avg       0.90      0.90      0.90       460
# weighted avg       0.90      0.90      0.90       460
#
# Training with: Epochs=10, Hidden Layer Size=64, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 11s 147ms/step - loss: 0.3522 - accuracy: 0.8435 - val_loss: 0.2016 - val_accuracy: 0.9283
# Epoch 2/10
# 58/58 [==============================] - 7s 126ms/step - loss: 0.1929 - accuracy: 0.9207 - val_loss: 0.2074 - val_accuracy: 0.9217
# Epoch 3/10
# 58/58 [==============================] - 8s 129ms/step - loss: 0.1518 - accuracy: 0.9386 - val_loss: 0.2052 - val_accuracy: 0.9174
# Epoch 4/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1144 - accuracy: 0.9587 - val_loss: 0.1977 - val_accuracy: 0.9174
# Epoch 5/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0962 - accuracy: 0.9625 - val_loss: 0.2082 - val_accuracy: 0.9196
# Epoch 6/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0681 - accuracy: 0.9810 - val_loss: 0.2120 - val_accuracy: 0.9217
# Epoch 7/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0585 - accuracy: 0.9821 - val_loss: 0.2198 - val_accuracy: 0.9261
# Epoch 8/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0375 - accuracy: 0.9929 - val_loss: 0.2459 - val_accuracy: 0.9217
# Epoch 9/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0289 - accuracy: 0.9957 - val_loss: 0.2551 - val_accuracy: 0.9022
# Epoch 10/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0199 - accuracy: 0.9984 - val_loss: 0.2509 - val_accuracy: 0.9217
# 15/15 [==============================] - 2s 99ms/step - loss: 0.2509 - accuracy: 0.9217
# Last Validation Accuracy: 0.9217391014099121
# 1/1 [==============================] - 1s 732ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 728ms/step
# F1 Score: 0.9217332123411979
# Precision: 0.9218667271764616
# Recall: 0.9217391304347826
# Confusion Matrix:
#  [[210  20]
#  [ 16 214]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.93      0.91      0.92       230
#     01-whole       0.91      0.93      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=64, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 150ms/step - loss: 0.3342 - accuracy: 0.8603 - val_loss: 0.2138 - val_accuracy: 0.9261
# Epoch 2/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2110 - accuracy: 0.9179 - val_loss: 0.1999 - val_accuracy: 0.9283
# Epoch 3/10
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1878 - accuracy: 0.9223 - val_loss: 0.1990 - val_accuracy: 0.9217
# Epoch 4/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1581 - accuracy: 0.9364 - val_loss: 0.1866 - val_accuracy: 0.9326
# Epoch 5/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1353 - accuracy: 0.9435 - val_loss: 0.1942 - val_accuracy: 0.9261
# Epoch 6/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1126 - accuracy: 0.9630 - val_loss: 0.2009 - val_accuracy: 0.9217
# Epoch 7/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1034 - accuracy: 0.9625 - val_loss: 0.2207 - val_accuracy: 0.9217
# Epoch 8/10
# 58/58 [==============================] - 7s 129ms/step - loss: 0.0955 - accuracy: 0.9614 - val_loss: 0.2072 - val_accuracy: 0.9261
# Epoch 9/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0763 - accuracy: 0.9750 - val_loss: 0.2119 - val_accuracy: 0.9174
# Epoch 10/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0645 - accuracy: 0.9826 - val_loss: 0.2120 - val_accuracy: 0.9217
# 15/15 [==============================] - 2s 102ms/step - loss: 0.2120 - accuracy: 0.9217
# Last Validation Accuracy: 0.9217391014099121
# 1/1 [==============================] - 1s 824ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 1s 769ms/step
# F1 Score: 0.9217376509952929
# Precision: 0.921771022383545
# Recall: 0.9217391304347826
# Confusion Matrix:
#  [[211  19]
#  [ 17 213]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.93      0.92      0.92       230
#     01-whole       0.92      0.93      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=128, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 11s 145ms/step - loss: 0.3033 - accuracy: 0.8663 - val_loss: 0.2214 - val_accuracy: 0.9174
# Epoch 2/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1851 - accuracy: 0.9250 - val_loss: 0.2165 - val_accuracy: 0.9065
# Epoch 3/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1291 - accuracy: 0.9522 - val_loss: 0.2414 - val_accuracy: 0.9022
# Epoch 4/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0946 - accuracy: 0.9658 - val_loss: 0.2081 - val_accuracy: 0.9196
# Epoch 5/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0715 - accuracy: 0.9755 - val_loss: 0.2230 - val_accuracy: 0.9196
# Epoch 6/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0481 - accuracy: 0.9908 - val_loss: 0.2189 - val_accuracy: 0.9174
# Epoch 7/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0461 - accuracy: 0.9870 - val_loss: 0.2370 - val_accuracy: 0.9217
# Epoch 8/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0245 - accuracy: 0.9957 - val_loss: 0.2430 - val_accuracy: 0.9217
# Epoch 9/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0145 - accuracy: 0.9995 - val_loss: 0.2650 - val_accuracy: 0.9109
# Epoch 10/10
# 58/58 [==============================] - 7s 129ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9196
# 15/15 [==============================] - 2s 99ms/step - loss: 0.2581 - accuracy: 0.9196
# Last Validation Accuracy: 0.9195652008056641
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 727ms/step
# F1 Score: 0.9195344153480302
# Precision: 0.9202086370434882
# Recall: 0.9195652173913044
# Confusion Matrix:
#  [[216  14]
#  [ 23 207]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.90      0.94      0.92       230
#     01-whole       0.94      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=128, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 11s 145ms/step - loss: 0.3447 - accuracy: 0.8565 - val_loss: 0.2185 - val_accuracy: 0.9261
# Epoch 2/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1812 - accuracy: 0.9288 - val_loss: 0.2343 - val_accuracy: 0.9152
# Epoch 3/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.1421 - accuracy: 0.9424 - val_loss: 0.2206 - val_accuracy: 0.9196
# Epoch 4/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1136 - accuracy: 0.9527 - val_loss: 0.2133 - val_accuracy: 0.9152
# Epoch 5/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0771 - accuracy: 0.9739 - val_loss: 0.2150 - val_accuracy: 0.9109
# Epoch 6/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0592 - accuracy: 0.9815 - val_loss: 0.2309 - val_accuracy: 0.9196
# Epoch 7/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.0457 - accuracy: 0.9864 - val_loss: 0.2664 - val_accuracy: 0.9000
# Epoch 8/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0347 - accuracy: 0.9913 - val_loss: 0.2408 - val_accuracy: 0.9130
# Epoch 9/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0230 - accuracy: 0.9957 - val_loss: 0.2722 - val_accuracy: 0.9109
# Epoch 10/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0154 - accuracy: 0.9995 - val_loss: 0.2710 - val_accuracy: 0.9239
# 15/15 [==============================] - 2s 104ms/step - loss: 0.2710 - accuracy: 0.9239
# Last Validation Accuracy: 0.9239130616188049
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 1s 820ms/step
# F1 Score: 0.9238695095021255
# Precision: 0.924884897402376
# Recall: 0.9239130434782609
# Confusion Matrix:
#  [[218  12]
#  [ 23 207]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.90      0.95      0.93       230
#     01-whole       0.95      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=128, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 11s 148ms/step - loss: 0.3339 - accuracy: 0.8522 - val_loss: 0.2136 - val_accuracy: 0.9261
# Epoch 2/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.2072 - accuracy: 0.9130 - val_loss: 0.2210 - val_accuracy: 0.9196
# Epoch 3/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1642 - accuracy: 0.9321 - val_loss: 0.2188 - val_accuracy: 0.9174
# Epoch 4/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.1534 - accuracy: 0.9370 - val_loss: 0.2274 - val_accuracy: 0.9130
# Epoch 5/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1333 - accuracy: 0.9462 - val_loss: 0.2125 - val_accuracy: 0.9174
# Epoch 6/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1055 - accuracy: 0.9603 - val_loss: 0.2025 - val_accuracy: 0.9239
# Epoch 7/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0886 - accuracy: 0.9658 - val_loss: 0.2129 - val_accuracy: 0.9196
# Epoch 8/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0759 - accuracy: 0.9745 - val_loss: 0.2145 - val_accuracy: 0.9239
# Epoch 9/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0632 - accuracy: 0.9793 - val_loss: 0.2250 - val_accuracy: 0.9196
# Epoch 10/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0663 - accuracy: 0.9793 - val_loss: 0.2420 - val_accuracy: 0.9196
# 15/15 [==============================] - 2s 103ms/step - loss: 0.2420 - accuracy: 0.9196
# Last Validation Accuracy: 0.9195652008056641
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 757ms/step
# F1 Score: 0.9193972314701244
# Precision: 0.9230923197163499
# Recall: 0.9195652173913044
# Confusion Matrix:
#  [[222   8]
#  [ 29 201]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.88      0.97      0.92       230
#     01-whole       0.96      0.87      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=256, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 11s 146ms/step - loss: 0.4192 - accuracy: 0.8228 - val_loss: 0.2244 - val_accuracy: 0.9174
# Epoch 2/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1842 - accuracy: 0.9261 - val_loss: 0.2089 - val_accuracy: 0.9261
# Epoch 3/10
# 58/58 [==============================] - 8s 128ms/step - loss: 0.1413 - accuracy: 0.9446 - val_loss: 0.2476 - val_accuracy: 0.9087
# Epoch 4/10
# 58/58 [==============================] - 8s 143ms/step - loss: 0.1098 - accuracy: 0.9614 - val_loss: 0.2094 - val_accuracy: 0.9196
# Epoch 5/10
# 58/58 [==============================] - 8s 129ms/step - loss: 0.0663 - accuracy: 0.9821 - val_loss: 0.1960 - val_accuracy: 0.9326
# Epoch 6/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0505 - accuracy: 0.9848 - val_loss: 0.2195 - val_accuracy: 0.9239
# Epoch 7/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0388 - accuracy: 0.9897 - val_loss: 0.2424 - val_accuracy: 0.9174
# Epoch 8/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0270 - accuracy: 0.9962 - val_loss: 0.2381 - val_accuracy: 0.9109
# Epoch 9/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.2359 - val_accuracy: 0.9283
# Epoch 10/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.2413 - val_accuracy: 0.9196
# 15/15 [==============================] - 2s 107ms/step - loss: 0.2413 - accuracy: 0.9196
# Last Validation Accuracy: 0.9195652008056641
# 1/1 [==============================] - 1s 814ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 1s 772ms/step
# F1 Score: 0.9195557131041002
# Precision: 0.9197635933806146
# Recall: 0.9195652173913044
# Confusion Matrix:
#  [[214  16]
#  [ 21 209]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.91      0.93      0.92       230
#     01-whole       0.93      0.91      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=256, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 11s 144ms/step - loss: 0.3237 - accuracy: 0.8674 - val_loss: 0.2004 - val_accuracy: 0.9196
# Epoch 2/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1595 - accuracy: 0.9337 - val_loss: 0.2271 - val_accuracy: 0.9174
# Epoch 3/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1257 - accuracy: 0.9484 - val_loss: 0.2330 - val_accuracy: 0.9174
# Epoch 4/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1015 - accuracy: 0.9603 - val_loss: 0.2350 - val_accuracy: 0.9196
# Epoch 5/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0623 - accuracy: 0.9793 - val_loss: 0.2617 - val_accuracy: 0.9196
# Epoch 6/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0505 - accuracy: 0.9799 - val_loss: 0.3266 - val_accuracy: 0.9087
# Epoch 7/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0324 - accuracy: 0.9918 - val_loss: 0.2533 - val_accuracy: 0.9130
# Epoch 8/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0176 - accuracy: 0.9984 - val_loss: 0.2609 - val_accuracy: 0.9217
# Epoch 9/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.3041 - val_accuracy: 0.9239
# Epoch 10/10
# 58/58 [==============================] - 8s 136ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2856 - val_accuracy: 0.9217
# 15/15 [==============================] - 2s 105ms/step - loss: 0.2856 - accuracy: 0.9217
# Last Validation Accuracy: 0.9217391014099121
# 1/1 [==============================] - 1s 726ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 711ms/step
# F1 Score: 0.9216858353510896
# Precision: 0.9228902873606794
# Recall: 0.9217391304347826
# Confusion Matrix:
#  [[218  12]
#  [ 24 206]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.90      0.95      0.92       230
#     01-whole       0.94      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=10, Hidden Layer Size=256, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/10
# 58/58 [==============================] - 12s 155ms/step - loss: 0.3552 - accuracy: 0.8315 - val_loss: 0.2309 - val_accuracy: 0.9109
# Epoch 2/10
# 58/58 [==============================] - 8s 134ms/step - loss: 0.2012 - accuracy: 0.9207 - val_loss: 0.2005 - val_accuracy: 0.9304
# Epoch 3/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.1596 - accuracy: 0.9353 - val_loss: 0.2317 - val_accuracy: 0.9043
# Epoch 4/10
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1406 - accuracy: 0.9429 - val_loss: 0.1931 - val_accuracy: 0.9326
# Epoch 5/10
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1162 - accuracy: 0.9511 - val_loss: 0.2505 - val_accuracy: 0.8957
# Epoch 6/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0934 - accuracy: 0.9674 - val_loss: 0.2520 - val_accuracy: 0.9130
# Epoch 7/10
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0795 - accuracy: 0.9712 - val_loss: 0.2184 - val_accuracy: 0.9152
# Epoch 8/10
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0686 - accuracy: 0.9804 - val_loss: 0.2288 - val_accuracy: 0.9174
# Epoch 9/10
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0562 - accuracy: 0.9821 - val_loss: 0.2335 - val_accuracy: 0.9174
# Epoch 10/10
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0556 - accuracy: 0.9788 - val_loss: 0.2405 - val_accuracy: 0.9174
# 15/15 [==============================] - 2s 106ms/step - loss: 0.2405 - accuracy: 0.9174
# Last Validation Accuracy: 0.917391300201416
# 1/1 [==============================] - 1s 786ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 1s 832ms/step
# F1 Score: 0.9173663111716208
# Precision: 0.9178968884851239
# Recall: 0.9173913043478261
# Confusion Matrix:
#  [[207  23]
#  [ 15 215]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.93      0.90      0.92       230
#     01-whole       0.90      0.93      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=15, Hidden Layer Size=64, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 11s 141ms/step - loss: 0.3435 - accuracy: 0.8478 - val_loss: 0.2004 - val_accuracy: 0.9326
# Epoch 2/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.1845 - accuracy: 0.9299 - val_loss: 0.1957 - val_accuracy: 0.9326
# Epoch 3/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1484 - accuracy: 0.9402 - val_loss: 0.1918 - val_accuracy: 0.9239
# Epoch 4/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.1131 - accuracy: 0.9560 - val_loss: 0.1984 - val_accuracy: 0.9217
# Epoch 5/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0931 - accuracy: 0.9625 - val_loss: 0.2108 - val_accuracy: 0.9261
# ...
# 1/1 [==============================] - 1s 750ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 737ms/step
# F1 Score: 0.9217021276595745
# Precision: 0.9225378787878789
# Recall: 0.9217391304347826
# Confusion Matrix:
#  [[217  13]
#  [ 23 207]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.90      0.94      0.92       230
#     01-whole       0.94      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=15, Hidden Layer Size=128, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 11s 145ms/step - loss: 0.3833 - accuracy: 0.8196 - val_loss: 0.2488 - val_accuracy: 0.8913
# Epoch 2/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2305 - accuracy: 0.9049 - val_loss: 0.2016 - val_accuracy: 0.9348
# Epoch 3/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1750 - accuracy: 0.9277 - val_loss: 0.1946 - val_accuracy: 0.9348
# Epoch 4/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.1531 - accuracy: 0.9386 - val_loss: 0.2007 - val_accuracy: 0.9239
# Epoch 5/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1337 - accuracy: 0.9478 - val_loss: 0.2014 - val_accuracy: 0.9239
# Epoch 6/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.1151 - accuracy: 0.9538 - val_loss: 0.2004 - val_accuracy: 0.9239
# Epoch 7/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0971 - accuracy: 0.9663 - val_loss: 0.2284 - val_accuracy: 0.9152
# Epoch 8/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0917 - accuracy: 0.9668 - val_loss: 0.2318 - val_accuracy: 0.9217
# Epoch 9/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0742 - accuracy: 0.9739 - val_loss: 0.2196 - val_accuracy: 0.9217
# Epoch 10/15
# 58/58 [==============================] - 8s 141ms/step - loss: 0.0637 - accuracy: 0.9826 - val_loss: 0.2254 - val_accuracy: 0.9087
# Epoch 11/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.0522 - accuracy: 0.9897 - val_loss: 0.2270 - val_accuracy: 0.9196
# Epoch 12/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0475 - accuracy: 0.9897 - val_loss: 0.2487 - val_accuracy: 0.9174
# Epoch 13/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.0462 - accuracy: 0.9902 - val_loss: 0.2609 - val_accuracy: 0.9174
# Epoch 14/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0405 - accuracy: 0.9940 - val_loss: 0.2599 - val_accuracy: 0.9087
# Epoch 15/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0278 - accuracy: 0.9973 - val_loss: 0.2602 - val_accuracy: 0.9174
# 15/15 [==============================] - 2s 96ms/step - loss: 0.2602 - accuracy: 0.9174
# Last Validation Accuracy: 0.917391300201416
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 1s 810ms/step
# F1 Score: 0.9173772475468417
# Precision: 0.9176755447941888
# Recall: 0.9173913043478261
# Confusion Matrix:
#  [[214  16]
#  [ 22 208]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.91      0.93      0.92       230
#     01-whole       0.93      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=15, Hidden Layer Size=256, Activation=relu
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 11s 148ms/step - loss: 0.3373 - accuracy: 0.8609 - val_loss: 0.2563 - val_accuracy: 0.8848
# Epoch 2/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1780 - accuracy: 0.9245 - val_loss: 0.2097 - val_accuracy: 0.9239
# Epoch 3/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1304 - accuracy: 0.9478 - val_loss: 0.2106 - val_accuracy: 0.9217
# Epoch 4/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0859 - accuracy: 0.9701 - val_loss: 0.2303 - val_accuracy: 0.9217
# Epoch 5/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0635 - accuracy: 0.9821 - val_loss: 0.2080 - val_accuracy: 0.9217
# Epoch 6/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0442 - accuracy: 0.9880 - val_loss: 0.2539 - val_accuracy: 0.9109
# Epoch 7/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0475 - accuracy: 0.9848 - val_loss: 0.2494 - val_accuracy: 0.9174
# Epoch 8/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0308 - accuracy: 0.9935 - val_loss: 0.2527 - val_accuracy: 0.9217
# Epoch 9/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0129 - accuracy: 0.9995 - val_loss: 0.2506 - val_accuracy: 0.9174
# Epoch 10/15
# 58/58 [==============================] - 7s 129ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.9217
# Epoch 11/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2826 - val_accuracy: 0.9217
# Epoch 12/15
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2883 - val_accuracy: 0.9217
# Epoch 13/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2965 - val_accuracy: 0.9261
# Epoch 14/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.3004 - val_accuracy: 0.9217
# Epoch 15/15
# 58/58 [==============================] - 7s 129ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3109 - val_accuracy: 0.9130
# 15/15 [==============================] - 2s 104ms/step - loss: 0.3109 - accuracy: 0.9130
# Last Validation Accuracy: 0.9130434989929199
# 1/1 [==============================] - 1s 739ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 1s 744ms/step
# F1 Score: 0.9130418344392144
# Precision: 0.9130747126436781
# Recall: 0.9130434782608695
# Confusion Matrix:
#  [[209  21]
#  [ 19 211]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.92      0.91      0.91       230
#     01-whole       0.91      0.92      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460
#
# Training with: Epochs=15, Hidden Layer Size=256, Activation=tanh
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 12s 156ms/step - loss: 0.3550 - accuracy: 0.8511 - val_loss: 0.2336 - val_accuracy: 0.9130
# Epoch 2/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1775 - accuracy: 0.9277 - val_loss: 0.2089 - val_accuracy: 0.9261
# Epoch 3/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.1305 - accuracy: 0.9473 - val_loss: 0.1822 - val_accuracy: 0.9348
# Epoch 4/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0834 - accuracy: 0.9728 - val_loss: 0.2385 - val_accuracy: 0.9152
# Epoch 5/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0686 - accuracy: 0.9717 - val_loss: 0.2337 - val_accuracy: 0.9109
# Epoch 6/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0556 - accuracy: 0.9810 - val_loss: 0.2126 - val_accuracy: 0.9196
# Epoch 7/15
# 58/58 [==============================] - 8s 137ms/step - loss: 0.0850 - accuracy: 0.9614 - val_loss: 0.2563 - val_accuracy: 0.9283
# Epoch 8/15
# 58/58 [==============================] - 8s 138ms/step - loss: 0.0332 - accuracy: 0.9908 - val_loss: 0.2269 - val_accuracy: 0.9239
# Epoch 9/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.0215 - accuracy: 0.9962 - val_loss: 0.2538 - val_accuracy: 0.9239
# Epoch 10/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2582 - val_accuracy: 0.9239
# Epoch 11/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2771 - val_accuracy: 0.9217
# Epoch 12/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9217
# Epoch 13/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.9196
# Epoch 14/15
# 58/58 [==============================] - 7s 129ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2845 - val_accuracy: 0.9239
# Epoch 15/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2921 - val_accuracy: 0.9196
# 15/15 [==============================] - 2s 103ms/step - loss: 0.2921 - accuracy: 0.9196
# Last Validation Accuracy: 0.9195652008056641
# 1/1 [==============================] - 1s 849ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 747ms/step
# F1 Score: 0.9195465868750325
# Precision: 0.9199542108947798
# Recall: 0.9195652173913044
# Confusion Matrix:
#  [[215  15]
#  [ 22 208]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.91      0.93      0.92       230
#     01-whole       0.93      0.90      0.92       230
#
#     accuracy                           0.92       460
#    macro avg       0.92      0.92      0.92       460
# weighted avg       0.92      0.92      0.92       460
#
# Training with: Epochs=15, Hidden Layer Size=256, Activation=sigmoid
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# Epoch 1/15
# 58/58 [==============================] - 11s 146ms/step - loss: 0.2941 - accuracy: 0.8712 - val_loss: 0.2034 - val_accuracy: 0.9283
# Epoch 2/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1835 - accuracy: 0.9201 - val_loss: 0.2089 - val_accuracy: 0.9174
# Epoch 3/15
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1659 - accuracy: 0.9326 - val_loss: 0.2287 - val_accuracy: 0.9065
# Epoch 4/15
# 58/58 [==============================] - 8s 136ms/step - loss: 0.1276 - accuracy: 0.9500 - val_loss: 0.2026 - val_accuracy: 0.9217
# Epoch 5/15
# 58/58 [==============================] - 8s 137ms/step - loss: 0.1061 - accuracy: 0.9560 - val_loss: 0.2152 - val_accuracy: 0.9174
# Epoch 6/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1107 - accuracy: 0.9543 - val_loss: 0.2135 - val_accuracy: 0.9217
# Epoch 7/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0875 - accuracy: 0.9625 - val_loss: 0.2241 - val_accuracy: 0.9174
# Epoch 8/15
# 58/58 [==============================] - 8s 135ms/step - loss: 0.0599 - accuracy: 0.9804 - val_loss: 0.2178 - val_accuracy: 0.9174
# Epoch 9/15
# 58/58 [==============================] - 8s 132ms/step - loss: 0.0514 - accuracy: 0.9853 - val_loss: 0.2474 - val_accuracy: 0.9174
# Epoch 10/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0417 - accuracy: 0.9902 - val_loss: 0.2393 - val_accuracy: 0.9130
# Epoch 11/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0339 - accuracy: 0.9946 - val_loss: 0.2497 - val_accuracy: 0.9174
# Epoch 12/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.0325 - accuracy: 0.9940 - val_loss: 0.2876 - val_accuracy: 0.9196
# Epoch 13/15
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0262 - accuracy: 0.9957 - val_loss: 0.2650 - val_accuracy: 0.9174
# Epoch 14/15
# 58/58 [==============================] - 8s 133ms/step - loss: 0.0181 - accuracy: 0.9989 - val_loss: 0.2792 - val_accuracy: 0.9217
# Epoch 15/15
# 58/58 [==============================] - 7s 128ms/step - loss: 0.0145 - accuracy: 0.9989 - val_loss: 0.2902 - val_accuracy: 0.9130
# 15/15 [==============================] - 2s 104ms/step - loss: 0.2902 - accuracy: 0.9130
# Last Validation Accuracy: 0.9130434989929199
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 1s 701ms/step
# F1 Score: 0.9130418344392144
# Precision: 0.9130747126436781
# Recall: 0.9130434782608695
# Confusion Matrix:
#  [[211  19]
#  [ 21 209]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    00-damage       0.91      0.92      0.91       230
#     01-whole       0.92      0.91      0.91       230
#
#     accuracy                           0.91       460
#    macro avg       0.91      0.91      0.91       460
# weighted avg       0.91      0.91      0.91       460

# %%
# Print the best hyperparameters and the best validation accuracy
print("Best Hyperparameters: ", best_params)
print("Best Validation Accuracy: ", best_score)

# Create a DataFrame from the results list
df = pd.DataFrame(results)

# Group the DataFrame by the 'Activation' column
grouped = df.groupby('Activation')

# Print the grouped DataFrame
for name, group in grouped:
    print(name)
    print(group)
# Out:
# Best Hyperparameters:  {'epochs': 15, 'hidden_layer_size': 64, 'activation': 'relu'}
# Best Validation Accuracy:  0.928260862827301
# relu
#     Epochs  Hidden Layer Size Activation  Validation Accuracy
# 0        5                 64       relu             0.913043
# 3        5                128       relu             0.921739
# 6        5                256       relu             0.926087
# 9       10                 64       relu             0.902174
# 12      10                128       relu             0.919565
# 15      10                256       relu             0.919565
# 18      15                 64       relu             0.928261
# 21      15                128       relu             0.923913
# 24      15                256       relu             0.913043
# sigmoid
#     Epochs  Hidden Layer Size Activation  Validation Accuracy
# 2        5                 64    sigmoid             0.915217
# 5        5                128    sigmoid             0.923913
# 8        5                256    sigmoid             0.915217
# 11      10                 64    sigmoid             0.921739
# 14      10                128    sigmoid             0.919565
# 17      10                256    sigmoid             0.917391
# 20      15                 64    sigmoid             0.917391
# 23      15                128    sigmoid             0.917391
# 26      15                256    sigmoid             0.913043
# tanh
#     Epochs  Hidden Layer Size Activation  Validation Accuracy
# 1        5                 64       tanh             0.921739
# 4        5                128       tanh             0.910870
# 7        5                256       tanh             0.923913
# 10      10                 64       tanh             0.921739
# 13      10                128       tanh             0.923913
# 16      10                256       tanh             0.921739
# 19      15                 64       tanh             0.917391
# 22      15                128       tanh             0.921739
# 25      15                256       tanh             0.919565
